# %%
# Import the required Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the dataset
data=pd.read_csv('collegePlace.csv')

# %%
data.head()
# Out:
#    Age  Gender                         Stream  Internships  CGPA  Hostel  \
# 0   22    Male  Electronics And Communication            1     8       1
# 1   21  Female               Computer Science            0     7       1
# 2   22  Female         Information Technology            1     6       0
# 3   21    Male         Information Technology            0     8       0
# 4   22    Male                     Mechanical            0     8       1
#
#    HistoryOfBacklogs  PlacedOrNot
# 0                  1            1
# 1                  1            1
# 2                  0            1
# 3                  1            1
# 4                  0            1

# %%
# checking the dataype of the parameters(Columns)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2966 entries, 0 to 2965
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                2966 non-null   int64
#  1   Gender             2966 non-null   object
#  2   Stream             2966 non-null   object
#  3   Internships        2966 non-null   int64
#  4   CGPA               2966 non-null   int64
#  5   Hostel             2966 non-null   int64
#  6   HistoryOfBacklogs  2966 non-null   int64
#  7   PlacedOrNot        2966 non-null   int64
# dtypes: int64(6), object(2)
# memory usage: 185.5+ KB

# %%
# To know columns
data.columns
# Out:
# Index(['Age', 'Gender', 'Stream', 'Internships', 'CGPA', 'Hostel',
#        'HistoryOfBacklogs', 'PlacedOrNot'],
#       dtype='object')

# %%
# Descriptive Analysis
data.describe()
# Out:
#                Age  Internships         CGPA       Hostel  HistoryOfBacklogs  \
# count  2966.000000  2966.000000  2966.000000  2966.000000        2966.000000
# mean     21.485840     0.703641     7.073837     0.269049           0.192178
# std       1.324933     0.740197     0.967748     0.443540           0.394079
# min      19.000000     0.000000     5.000000     0.000000           0.000000
# 25%      21.000000     0.000000     6.000000     0.000000           0.000000
# 50%      21.000000     1.000000     7.000000     0.000000           0.000000
# 75%      22.000000     1.000000     8.000000     1.000000           0.000000
# max      30.000000     3.000000     9.000000     1.000000           1.000000
#
#        PlacedOrNot
# count  2966.000000
# mean      0.552596
# std       0.497310
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
#Checking null values
data.isnull().any()
# Out:
# Age                  False
# Gender               False
# Stream               False
# Internships          False
# CGPA                 False
# Hostel               False
# HistoryOfBacklogs    False
# PlacedOrNot          False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# Age                  0
# Gender               0
# Stream               0
# Internships          0
# CGPA                 0
# Hostel               0
# HistoryOfBacklogs    0
# PlacedOrNot          0
# dtype: int64

# %%
#BarPlot
plt.bar(data['Age'],data['PlacedOrNot'])
# Out:
# <BarContainer object of 2966 artists>

# %%
#BarPlot
plt.bar(data['Gender'],data['PlacedOrNot'])
# Out:
# <BarContainer object of 2966 artists>

# %%
#BarPlot
plt.bar(data['Stream'],data['PlacedOrNot'])
# Out:
# <BarContainer object of 2966 artists>

# %%
#BarPlot
plt.bar(data['Internships'],data['PlacedOrNot'])
# Out:
# <BarContainer object of 2966 artists>

# %%
#BarPlot
plt.bar(data['CGPA'],data['PlacedOrNot'])
# Out:
# <BarContainer object of 2966 artists>

# %%
#BarPlot
plt.bar(data['Hostel'],data['PlacedOrNot'])
# Out:
# <BarContainer object of 2966 artists>

# %%
#BarPlot
plt.bar(data['HistoryOfBacklogs'],data['PlacedOrNot'])
# Out:
# <BarContainer object of 2966 artists>

# %%
#Pie Chart
plt.pie(data['PlacedOrNot'],autopct='%.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x17a65ca9540>,
#   <matplotlib.patches.Wedge at 0x17a65ca9450>,
#   <matplotlib.patches.Wedge at 0x17a65caa110>,
#   <matplotlib.patches.Wedge at 0x17a65caa7a0>,
#   <matplotlib.patches.Wedge at 0x17a65caae30>,
#   <matplotlib.patches.Wedge at 0x17a65cab4c0>,
#   <matplotlib.patches.Wedge at 0x17a65cabb50>,
#   <matplotlib.patches.Wedge at 0x17a65cdc220>,
#   <matplotlib.patches.Wedge at 0x17a65cdc8b0>,
#   <matplotlib.patches.Wedge at 0x17a65cdcf40>,
#   <matplotlib.patches.Wedge at 0x17a65ca9510>,
#   <matplotlib.patches.Wedge at 0x17a65cddc30>,
#   <matplotlib.patches.Wedge at 0x17a65cde2c0>,
#   <matplotlib.patches.Wedge at 0x17a65cde950>,
#   <matplotlib.patches.Wedge at 0x17a65cdefe0>,
#   <matplotlib.patches.Wedge at 0x17a65cdf670>,
#   <matplotlib.patches.Wedge at 0x17a65cdfd00>,
#   <matplotlib.patches.Wedge at 0x17a65d1c3d0>,
#   <matplotlib.patches.Wedge at 0x17a65d1ca60>,
#   <matplotlib.patches.Wedge at 0x17a65d1d0f0>,
#   <matplotlib.patches.Wedge at 0x17a65d1d780>,
#   <matplotlib.patches.Wedge at 0x17a65d1de10>,
#   <matplotlib.patches.Wedge at 0x17a65d1e4a0>,
#   <matplotlib.patches.Wedge at 0x17a65d1eb30>,
#   <matplotlib.patches.Wedge at 0x17a65d1f1c0>,
#   <matplotlib.patches.Wedge at 0x17a65d1f850>,
#   <matplotlib.patches.Wedge at 0x17a65d1fee0>,
#   <matplotlib.patches.Wedge at 0x17a65d505b0>,
#   <matplotlib.patches.Wedge at 0x17a65d50c40>,
#   <matplotlib.patches.Wedge at 0x17a65d512d0>,
#   <matplotlib.patches.Wedge at 0x17a65d51960>,
#   <matplotlib.patches.Wedge at 0x17a65d51ff0>,
#   <matplotlib.patches.Wedge at 0x17a65d52680>,
#   <matplotlib.patches.Wedge at 0x17a65d52d10>,
#   <matplotlib.patches.Wedge at 0x17a65d533a0>,
#   <matplotlib.patches.Wedge at 0x17a65d53a30>,
#   <matplotlib.patches.Wedge at 0x17a65b54100>,
#   <matplotlib.patches.Wedge at 0x17a65b54790>,
#   <matplotlib.patches.Wedge at 0x17a65b54d00>,
#   <matplotlib.patches.Wedge at 0x17a65b55390>,
#   <matplotlib.patches.Wedge at 0x17a65b55a20>,
#   <matplotlib.patches.Wedge at 0x17a65b560b0>,
#   <matplotlib.patches.Wedge at 0x17a65b56740>,
#   <matplotlib.patches.Wedge at 0x17a65b56dd0>,
#   <matplotlib.patches.Wedge at 0x17a65b57460>,
#   <matplotlib.patches.Wedge at 0x17a65b57af0>,
#   <matplotlib.patches.Wedge at 0x17a65b881c0>,
#   <matplotlib.patches.Wedge at 0x17a65b88850>,
#   <matplotlib.patches.Wedge at 0x17a65b88ee0>,
#   <matplotlib.patches.Wedge at 0x17a65b89570>,
#   <matplotlib.patches.Wedge at 0x17a65b89c00>,
#   <matplotlib.patches.Wedge at 0x17a65b8a290>,
#   <matplotlib.patches.Wedge at 0x17a65b8a920>,
#   <matplotlib.patches.Wedge at 0x17a65b8afb0>,
#   <matplotlib.patches.Wedge at 0x17a65b8b640>,
#   <matplotlib.patches.Wedge at 0x17a65b8bcd0>,
#   <matplotlib.patches.Wedge at 0x17a65bb83a0>,
#   <matplotlib.patches.Wedge at 0x17a65bb8a30>,
#   <matplotlib.patches.Wedge at 0x17a65bb90c0>,
#   <matplotlib.patches.Wedge at 0x17a65bb9750>,
#   <matplotlib.patches.Wedge at 0x17a65bb9de0>,
#   <matplotlib.patches.Wedge at 0x17a65bba470>,
#   <matplotlib.patches.Wedge at 0x17a65bbab00>,
#   <matplotlib.patches.Wedge at 0x17a65bbb190>,
#   <matplotlib.patches.Wedge at 0x17a65bbb820>,
#   <matplotlib.patches.Wedge at 0x17a65bbbeb0>,
#   <matplotlib.patches.Wedge at 0x17a65bf0580>,
#   <matplotlib.patches.Wedge at 0x17a65bf0c10>,
#   <matplotlib.patches.Wedge at 0x17a65bf12a0>,
#   <matplotlib.patches.Wedge at 0x17a65bf1930>,
#   <matplotlib.patches.Wedge at 0x17a65bf1fc0>,
#   <matplotlib.patches.Wedge at 0x17a65bf2650>,
#   <matplotlib.patches.Wedge at 0x17a65bf2ce0>,
#   <matplotlib.patches.Wedge at 0x17a65bf3370>,
#   <matplotlib.patches.Wedge at 0x17a65bf3a00>,
#   <matplotlib.patches.Wedge at 0x17a65d6c0d0>,
#   <matplotlib.patches.Wedge at 0x17a65d6c760>,
#   <matplotlib.patches.Wedge at 0x17a65d6cdf0>,
#   <matplotlib.patches.Wedge at 0x17a65d6d480>,
#   <matplotlib.patches.Wedge at 0x17a65d6db10>,
#   <matplotlib.patches.Wedge at 0x17a65d6e1a0>,
#   <matplotlib.patches.Wedge at 0x17a65d6e830>,
#   <matplotlib.patches.Wedge at 0x17a65d6eec0>,
#   <matplotlib.patches.Wedge at 0x17a65d6f550>,
#   <matplotlib.patches.Wedge at 0x17a65d6fbe0>,
#   <matplotlib.patches.Wedge at 0x17a65dac2b0>,
#   <matplotlib.patches.Wedge at 0x17a65dac940>,
#   <matplotlib.patches.Wedge at 0x17a65dacfd0>,
#   <matplotlib.patches.Wedge at 0x17a65dad660>,
#   <matplotlib.patches.Wedge at 0x17a65dadcf0>,
#   <matplotlib.patches.Wedge at 0x17a65dae380>,
#   <matplotlib.patches.Wedge at 0x17a65daea10>,
#   <matplotlib.patches.Wedge at 0x17a65daf0a0>,
#   <matplotlib.patches.Wedge at 0x17a65daf730>,
#   <matplotlib.patches.Wedge at 0x17a65dafdf0>,
#   <matplotlib.patches.Wedge at 0x17a65de84c0>,
#   <matplotlib.patches.Wedge at 0x17a65de8b50>,
#   <matplotlib.patches.Wedge at 0x17a65de91e0>,
#   <matplotlib.patches.Wedge at 0x17a65de9870>,
#   <matplotlib.patches.Wedge at 0x17a65de9f00>,
#   <matplotlib.patches.Wedge at 0x17a65dea590>,
#   <matplotlib.patches.Wedge at 0x17a65deac20>,
#   <matplotlib.patches.Wedge at 0x17a65deb2b0>,
#   <matplotlib.patches.Wedge at 0x17a65deb940>,
#   <matplotlib.patches.Wedge at 0x17a65debfd0>,
#   <matplotlib.patches.Wedge at 0x17a65e1c6a0>,
#   <matplotlib.patches.Wedge at 0x17a65e1cd30>,
#   <matplotlib.patches.Wedge at 0x17a65e1d3c0>,
#   <matplotlib.patches.Wedge at 0x17a65e1da50>,
#   <matplotlib.patches.Wedge at 0x17a65e1e0e0>,
#   <matplotlib.patches.Wedge at 0x17a65e1e770>,
#   <matplotlib.patches.Wedge at 0x17a65e1ee00>,
#   <matplotlib.patches.Wedge at 0x17a65e1f490>,
#   <matplotlib.patches.Wedge at 0x17a65e1fb20>,
#   <matplotlib.patches.Wedge at 0x17a65e601f0>,
#   <matplotlib.patches.Wedge at 0x17a65e60880>,
#   <matplotlib.patches.Wedge at 0x17a65e60f10>,
#   <matplotlib.patches.Wedge at 0x17a65e615a0>,
#   <matplotlib.patches.Wedge at 0x17a65e61c30>,
#   <matplotlib.patches.Wedge at 0x17a65e622c0>,
#   <matplotlib.patches.Wedge at 0x17a65e62950>,
#   <matplotlib.patches.Wedge at 0x17a65e62fe0>,
#   <matplotlib.patches.Wedge at 0x17a65e63670>,
#   <matplotlib.patches.Wedge at 0x17a65e63d00>,
#   <matplotlib.patches.Wedge at 0x17a65e943d0>,
#   <matplotlib.patches.Wedge at 0x17a65e94a60>,
#   <matplotlib.patches.Wedge at 0x17a65e950f0>,
#   <matplotlib.patches.Wedge at 0x17a65e95780>,
#   <matplotlib.patches.Wedge at 0x17a65e95e10>,
#   <matplotlib.patches.Wedge at 0x17a65e964a0>,
#   <matplotlib.patches.Wedge at 0x17a65e96b30>,
#   <matplotlib.patches.Wedge at 0x17a65e971c0>,
#   <matplotlib.patches.Wedge at 0x17a65e97850>,
#   <matplotlib.patches.Wedge at 0x17a65e97ee0>,
#   <matplotlib.patches.Wedge at 0x17a65ed45b0>,
#   <matplotlib.patches.Wedge at 0x17a65ed4c40>,
#   <matplotlib.patches.Wedge at 0x17a65ed52d0>,
#   <matplotlib.patches.Wedge at 0x17a65ed5960>,
#   <matplotlib.patches.Wedge at 0x17a65ed5ff0>,
#   <matplotlib.patches.Wedge at 0x17a65ed6680>,
#   <matplotlib.patches.Wedge at 0x17a65ed6d10>,
#   <matplotlib.patches.Wedge at 0x17a65ed73a0>,
#   <matplotlib.patches.Wedge at 0x17a65ed7a30>,
#   <matplotlib.patches.Wedge at 0x17a65f10100>,
#   <matplotlib.patches.Wedge at 0x17a65f10790>,
#   <matplotlib.patches.Wedge at 0x17a65f10e20>,
#   <matplotlib.patches.Wedge at 0x17a65f114b0>,
#   <matplotlib.patches.Wedge at 0x17a65f11b40>,
#   <matplotlib.patches.Wedge at 0x17a65f121d0>,
#   <matplotlib.patches.Wedge at 0x17a65f12860>,
#   <matplotlib.patches.Wedge at 0x17a65f12f20>,
#   <matplotlib.patches.Wedge at 0x17a65f135b0>,
#   <matplotlib.patches.Wedge at 0x17a65f13c40>,
#   <matplotlib.patches.Wedge at 0x17a65f40310>,
#   <matplotlib.patches.Wedge at 0x17a65f409a0>,
#   <matplotlib.patches.Wedge at 0x17a65f41030>,
#   <matplotlib.patches.Wedge at 0x17a65f416c0>,
#   <matplotlib.patches.Wedge at 0x17a65f41d50>,
#   <matplotlib.patches.Wedge at 0x17a65f423e0>,
#   <matplotlib.patches.Wedge at 0x17a65f42a70>,
#   <matplotlib.patches.Wedge at 0x17a65f43100>,
#   <matplotlib.patches.Wedge at 0x17a65f43790>,
#   <matplotlib.patches.Wedge at 0x17a65f43e20>,
#   <matplotlib.patches.Wedge at 0x17a65f844f0>,
#   <matplotlib.patches.Wedge at 0x17a65f84b80>,
#   <matplotlib.patches.Wedge at 0x17a65f85210>,
#   <matplotlib.patches.Wedge at 0x17a65f858a0>,
#   <matplotlib.patches.Wedge at 0x17a65f85f30>,
#   <matplotlib.patches.Wedge at 0x17a65f865c0>,
#   <matplotlib.patches.Wedge at 0x17a65f86c50>,
#   <matplotlib.patches.Wedge at 0x17a65f872e0>,
#   <matplotlib.patches.Wedge at 0x17a65f87970>,
#   <matplotlib.patches.Wedge at 0x17a65fbc040>,
#   <matplotlib.patches.Wedge at 0x17a65fbc6d0>,
#   <matplotlib.patches.Wedge at 0x17a65fbcd60>,
#   <matplotlib.patches.Wedge at 0x17a65fbd3f0>,
#   <matplotlib.patches.Wedge at 0x17a65fbda80>,
#   <matplotlib.patches.Wedge at 0x17a65fbe110>,
#   <matplotlib.patches.Wedge at 0x17a65fbe7a0>,
#   <matplotlib.patches.Wedge at 0x17a65fbee30>,
#   <matplotlib.patches.Wedge at 0x17a65fbf4c0>,
#   <matplotlib.patches.Wedge at 0x17a65fbfb50>,
#   <matplotlib.patches.Wedge at 0x17a66000220>,
#   <matplotlib.patches.Wedge at 0x17a660008b0>,
#   <matplotlib.patches.Wedge at 0x17a66000f40>,
#   <matplotlib.patches.Wedge at 0x17a660015d0>,
#   <matplotlib.patches.Wedge at 0x17a66001c60>,
#   <matplotlib.patches.Wedge at 0x17a660022f0>,
#   <matplotlib.patches.Wedge at 0x17a66002980>,
#   <matplotlib.patches.Wedge at 0x17a66003010>,
#   <matplotlib.patches.Wedge at 0x17a660036a0>,
#   <matplotlib.patches.Wedge at 0x17a66003d30>,
#   <matplotlib.patches.Wedge at 0x17a66038400>,
#   <matplotlib.patches.Wedge at 0x17a66038a90>,
#   <matplotlib.patches.Wedge at 0x17a66039120>,
#   <matplotlib.patches.Wedge at 0x17a660397b0>,
#   <matplotlib.patches.Wedge at 0x17a66039e40>,
#   <matplotlib.patches.Wedge at 0x17a6603a4d0>,
#   <matplotlib.patches.Wedge at 0x17a6603ab60>,
#   <matplotlib.patches.Wedge at 0x17a6603b1f0>,
#   <matplotlib.patches.Wedge at 0x17a6603b880>,
#   <matplotlib.patches.Wedge at 0x17a6603bf10>,
#   <matplotlib.patches.Wedge at 0x17a660745e0>,
#   <matplotlib.patches.Wedge at 0x17a66074c70>,
#   <matplotlib.patches.Wedge at 0x17a66075300>,
#   <matplotlib.patches.Wedge at 0x17a66075990>,
#   <matplotlib.patches.Wedge at 0x17a66076020>,
#   <matplotlib.patches.Wedge at 0x17a660766b0>,
#   <matplotlib.patches.Wedge at 0x17a66076d40>,
#   <matplotlib.patches.Wedge at 0x17a660773d0>,
#   <matplotlib.patches.Wedge at 0x17a66077a60>,
#   <matplotlib.patches.Wedge at 0x17a660b0130>,
#   <matplotlib.patches.Wedge at 0x17a660b07c0>,
#   <matplotlib.patches.Wedge at 0x17a660b0e50>,
#   <matplotlib.patches.Wedge at 0x17a660b14e0>,
#   <matplotlib.patches.Wedge at 0x17a660b1b70>,
#   <matplotlib.patches.Wedge at 0x17a660b2200>,
#   <matplotlib.patches.Wedge at 0x17a660b2890>,
#   <matplotlib.patches.Wedge at 0x17a660b2f20>,
#   <matplotlib.patches.Wedge at 0x17a660b35b0>,
#   <matplotlib.patches.Wedge at 0x17a660b3c40>,
#   <matplotlib.patches.Wedge at 0x17a660ec310>,
#   <matplotlib.patches.Wedge at 0x17a660ec9a0>,
#   <matplotlib.patches.Wedge at 0x17a660ed030>,
#   <matplotlib.patches.Wedge at 0x17a660ed6c0>,
#   <matplotlib.patches.Wedge at 0x17a660edd50>,
#   <matplotlib.patches.Wedge at 0x17a660ee3e0>,
#   <matplotlib.patches.Wedge at 0x17a660eea70>,
#   <matplotlib.patches.Wedge at 0x17a660ef100>,
#   <matplotlib.patches.Wedge at 0x17a660ef790>,
#   <matplotlib.patches.Wedge at 0x17a660efe20>,
#   <matplotlib.patches.Wedge at 0x17a661284f0>,
#   <matplotlib.patches.Wedge at 0x17a66128b80>,
#   <matplotlib.patches.Wedge at 0x17a66129210>,
#   <matplotlib.patches.Wedge at 0x17a661298a0>,
#   <matplotlib.patches.Wedge at 0x17a66129f30>,
#   <matplotlib.patches.Wedge at 0x17a6612a5c0>,
#   <matplotlib.patches.Wedge at 0x17a6612ac50>,
#   <matplotlib.patches.Wedge at 0x17a6612b2e0>,
#   <matplotlib.patches.Wedge at 0x17a6612b970>,
#   <matplotlib.patches.Wedge at 0x17a66168040>,
#   <matplotlib.patches.Wedge at 0x17a661686d0>,
#   <matplotlib.patches.Wedge at 0x17a66168d60>,
#   <matplotlib.patches.Wedge at 0x17a661693f0>,
#   <matplotlib.patches.Wedge at 0x17a66169a80>,
#   <matplotlib.patches.Wedge at 0x17a6616a110>,
#   <matplotlib.patches.Wedge at 0x17a6616a7a0>,
#   <matplotlib.patches.Wedge at 0x17a6616ae30>,
#   <matplotlib.patches.Wedge at 0x17a6616b4c0>,
#   <matplotlib.patches.Wedge at 0x17a6616bb50>,
#   <matplotlib.patches.Wedge at 0x17a66198220>,
#   <matplotlib.patches.Wedge at 0x17a661988b0>,
#   <matplotlib.patches.Wedge at 0x17a66198f40>,
#   <matplotlib.patches.Wedge at 0x17a661995d0>,
#   <matplotlib.patches.Wedge at 0x17a66199c60>,
#   <matplotlib.patches.Wedge at 0x17a6619a2f0>,
#   <matplotlib.patches.Wedge at 0x17a6619a980>,
#   <matplotlib.patches.Wedge at 0x17a6619b010>,
#   <matplotlib.patches.Wedge at 0x17a6619b6a0>,
#   <matplotlib.patches.Wedge at 0x17a6619bd30>,
#   <matplotlib.patches.Wedge at 0x17a661d8400>,
#   <matplotlib.patches.Wedge at 0x17a661d8a90>,
#   <matplotlib.patches.Wedge at 0x17a661d9120>,
#   <matplotlib.patches.Wedge at 0x17a661d97b0>,
#   <matplotlib.patches.Wedge at 0x17a661d9e40>,
#   <matplotlib.patches.Wedge at 0x17a661da4d0>,
#   <matplotlib.patches.Wedge at 0x17a661dab60>,
#   <matplotlib.patches.Wedge at 0x17a661db1f0>,
#   <matplotlib.patches.Wedge at 0x17a661db880>,
#   <matplotlib.patches.Wedge at 0x17a661dbf10>,
#   <matplotlib.patches.Wedge at 0x17a662105e0>,
#   <matplotlib.patches.Wedge at 0x17a66210c70>,
#   <matplotlib.patches.Wedge at 0x17a66211300>,
#   <matplotlib.patches.Wedge at 0x17a66211990>,
#   <matplotlib.patches.Wedge at 0x17a66212020>,
#   <matplotlib.patches.Wedge at 0x17a662126b0>,
#   <matplotlib.patches.Wedge at 0x17a66212d40>,
#   <matplotlib.patches.Wedge at 0x17a662133d0>,
#   <matplotlib.patches.Wedge at 0x17a66213a60>,
#   <matplotlib.patches.Wedge at 0x17a66250130>,
#   <matplotlib.patches.Wedge at 0x17a662507c0>,
#   <matplotlib.patches.Wedge at 0x17a66250e50>,
#   <matplotlib.patches.Wedge at 0x17a662514e0>,
#   <matplotlib.patches.Wedge at 0x17a66251b70>,
#   <matplotlib.patches.Wedge at 0x17a66252200>,
#   <matplotlib.patches.Wedge at 0x17a66252890>,
#   <matplotlib.patches.Wedge at 0x17a66252f20>,
#   <matplotlib.patches.Wedge at 0x17a662535b0>,
#   <matplotlib.patches.Wedge at 0x17a66253c40>,
#   <matplotlib.patches.Wedge at 0x17a6628c310>,
#   <matplotlib.patches.Wedge at 0x17a6628c9a0>,
#   <matplotlib.patches.Wedge at 0x17a6628d030>,
#   <matplotlib.patches.Wedge at 0x17a6628d6c0>,
#   <matplotlib.patches.Wedge at 0x17a6628dd50>,
#   <matplotlib.patches.Wedge at 0x17a6628e3e0>,
#   <matplotlib.patches.Wedge at 0x17a6628ea70>,
#   <matplotlib.patches.Wedge at 0x17a6628f100>,
#   <matplotlib.patches.Wedge at 0x17a6628f790>,
#   <matplotlib.patches.Wedge at 0x17a6628fe20>,
#   <matplotlib.patches.Wedge at 0x17a662c44f0>,
#   <matplotlib.patches.Wedge at 0x17a662c4b80>,
#   <matplotlib.patches.Wedge at 0x17a662c5210>,
#   <matplotlib.patches.Wedge at 0x17a662c58a0>,
#   <matplotlib.patches.Wedge at 0x17a662c5f30>,
#   <matplotlib.patches.Wedge at 0x17a662c65c0>,
#   <matplotlib.patches.Wedge at 0x17a662c6c50>,
#   <matplotlib.patches.Wedge at 0x17a662c72e0>,
#   <matplotlib.patches.Wedge at 0x17a662c7970>,
#   <matplotlib.patches.Wedge at 0x17a66300040>,
#   <matplotlib.patches.Wedge at 0x17a663006d0>,
#   <matplotlib.patches.Wedge at 0x17a66300d60>,
#   <matplotlib.patches.Wedge at 0x17a663013f0>,
#   <matplotlib.patches.Wedge at 0x17a66301a80>,
#   <matplotlib.patches.Wedge at 0x17a66302110>,
#   <matplotlib.patches.Wedge at 0x17a663027a0>,
#   <matplotlib.patches.Wedge at 0x17a66302e30>,
#   <matplotlib.patches.Wedge at 0x17a663034c0>,
#   <matplotlib.patches.Wedge at 0x17a66303b50>,
#   <matplotlib.patches.Wedge at 0x17a6633c220>,
#   <matplotlib.patches.Wedge at 0x17a6633c8b0>,
#   <matplotlib.patches.Wedge at 0x17a6633cf40>,
#   <matplotlib.patches.Wedge at 0x17a6633d5d0>,
#   <matplotlib.patches.Wedge at 0x17a6633dc60>,
#   <matplotlib.patches.Wedge at 0x17a6633e320>,
#   <matplotlib.patches.Wedge at 0x17a6633e9b0>,
#   <matplotlib.patches.Wedge at 0x17a6633f040>,
#   <matplotlib.patches.Wedge at 0x17a6633f6d0>,
#   <matplotlib.patches.Wedge at 0x17a6633fd60>,
#   <matplotlib.patches.Wedge at 0x17a6637c430>,
#   <matplotlib.patches.Wedge at 0x17a6637cac0>,
#   <matplotlib.patches.Wedge at 0x17a6637d150>,
#   <matplotlib.patches.Wedge at 0x17a6637d7e0>,
#   <matplotlib.patches.Wedge at 0x17a6637de70>,
#   <matplotlib.patches.Wedge at 0x17a6637e500>,
#   <matplotlib.patches.Wedge at 0x17a6637eb90>,
#   <matplotlib.patches.Wedge at 0x17a6637f220>,
#   <matplotlib.patches.Wedge at 0x17a6637f8b0>,
#   <matplotlib.patches.Wedge at 0x17a6637ff40>,
#   <matplotlib.patches.Wedge at 0x17a663b8610>,
#   <matplotlib.patches.Wedge at 0x17a663b8ca0>,
#   <matplotlib.patches.Wedge at 0x17a663b9330>,
#   <matplotlib.patches.Wedge at 0x17a663b99c0>,
#   <matplotlib.patches.Wedge at 0x17a663ba050>,
#   <matplotlib.patches.Wedge at 0x17a663ba6e0>,
#   <matplotlib.patches.Wedge at 0x17a663bad70>,
#   <matplotlib.patches.Wedge at 0x17a663bb430>,
#   <matplotlib.patches.Wedge at 0x17a663bbac0>,
#   <matplotlib.patches.Wedge at 0x17a663e4190>,
#   <matplotlib.patches.Wedge at 0x17a663e4820>,
#   <matplotlib.patches.Wedge at 0x17a663e4eb0>,
#   <matplotlib.patches.Wedge at 0x17a663e5540>,
#   <matplotlib.patches.Wedge at 0x17a663e5bd0>,
#   <matplotlib.patches.Wedge at 0x17a663e6260>,
#   <matplotlib.patches.Wedge at 0x17a663e68f0>,
#   <matplotlib.patches.Wedge at 0x17a663e6f80>,
#   <matplotlib.patches.Wedge at 0x17a663e7610>,
#   <matplotlib.patches.Wedge at 0x17a663e7ca0>,
#   <matplotlib.patches.Wedge at 0x17a66428370>,
#   <matplotlib.patches.Wedge at 0x17a66428a00>,
#   <matplotlib.patches.Wedge at 0x17a66429090>,
#   <matplotlib.patches.Wedge at 0x17a66429720>,
#   <matplotlib.patches.Wedge at 0x17a66429db0>,
#   <matplotlib.patches.Wedge at 0x17a6642a440>,
#   <matplotlib.patches.Wedge at 0x17a6642ab00>,
#   <matplotlib.patches.Wedge at 0x17a6642b190>,
#   <matplotlib.patches.Wedge at 0x17a6642b820>,
#   <matplotlib.patches.Wedge at 0x17a6642beb0>,
#   <matplotlib.patches.Wedge at 0x17a66464580>,
#   <matplotlib.patches.Wedge at 0x17a66464c10>,
#   <matplotlib.patches.Wedge at 0x17a664652a0>,
#   <matplotlib.patches.Wedge at 0x17a66465930>,
#   <matplotlib.patches.Wedge at 0x17a66465fc0>,
#   <matplotlib.patches.Wedge at 0x17a66466650>,
#   <matplotlib.patches.Wedge at 0x17a66466ce0>,
#   <matplotlib.patches.Wedge at 0x17a66467370>,
#   <matplotlib.patches.Wedge at 0x17a66467a00>,
#   <matplotlib.patches.Wedge at 0x17a664a40d0>,
#   <matplotlib.patches.Wedge at 0x17a664a4760>,
#   <matplotlib.patches.Wedge at 0x17a664a4df0>,
#   <matplotlib.patches.Wedge at 0x17a664a5480>,
#   <matplotlib.patches.Wedge at 0x17a664a5b10>,
#   <matplotlib.patches.Wedge at 0x17a664a61a0>,
#   <matplotlib.patches.Wedge at 0x17a664a6830>,
#   <matplotlib.patches.Wedge at 0x17a664a6ec0>,
#   <matplotlib.patches.Wedge at 0x17a664a7550>,
#   <matplotlib.patches.Wedge at 0x17a664a7be0>,
#   <matplotlib.patches.Wedge at 0x17a664d82b0>,
#   <matplotlib.patches.Wedge at 0x17a664d8940>,
#   <matplotlib.patches.Wedge at 0x17a664d8fd0>,
#   <matplotlib.patches.Wedge at 0x17a664d9660>,
#   <matplotlib.patches.Wedge at 0x17a664d9cf0>,
#   <matplotlib.patches.Wedge at 0x17a664da380>,
#   <matplotlib.patches.Wedge at 0x17a664daa10>,
#   <matplotlib.patches.Wedge at 0x17a664db0a0>,
#   <matplotlib.patches.Wedge at 0x17a664db730>,
#   <matplotlib.patches.Wedge at 0x17a664dbdc0>,
#   <matplotlib.patches.Wedge at 0x17a66514490>,
#   <matplotlib.patches.Wedge at 0x17a66514b20>,
#   <matplotlib.patches.Wedge at 0x17a665151b0>,
#   <matplotlib.patches.Wedge at 0x17a66515840>,
#   <matplotlib.patches.Wedge at 0x17a66515ed0>,
#   <matplotlib.patches.Wedge at 0x17a66516560>,
#   <matplotlib.patches.Wedge at 0x17a66516bf0>,
#   <matplotlib.patches.Wedge at 0x17a66517280>,
#   <matplotlib.patches.Wedge at 0x17a66517910>,
#   <matplotlib.patches.Wedge at 0x17a66517fa0>,
#   <matplotlib.patches.Wedge at 0x17a66554670>,
#   <matplotlib.patches.Wedge at 0x17a66554d00>,
#   <matplotlib.patches.Wedge at 0x17a66555390>,
#   <matplotlib.patches.Wedge at 0x17a66555a20>,
#   <matplotlib.patches.Wedge at 0x17a665560b0>,
#   <matplotlib.patches.Wedge at 0x17a66556740>,
#   <matplotlib.patches.Wedge at 0x17a66556dd0>,
#   <matplotlib.patches.Wedge at 0x17a66557460>,
#   <matplotlib.patches.Wedge at 0x17a66557af0>,
#   <matplotlib.patches.Wedge at 0x17a665901c0>,
#   <matplotlib.patches.Wedge at 0x17a66590850>,
#   <matplotlib.patches.Wedge at 0x17a66590ee0>,
#   <matplotlib.patches.Wedge at 0x17a66591570>,
#   <matplotlib.patches.Wedge at 0x17a66591c00>,
#   <matplotlib.patches.Wedge at 0x17a66592290>,
#   <matplotlib.patches.Wedge at 0x17a66592920>,
#   <matplotlib.patches.Wedge at 0x17a66592fb0>,
#   <matplotlib.patches.Wedge at 0x17a66593640>,
#   <matplotlib.patches.Wedge at 0x17a66593cd0>,
#   <matplotlib.patches.Wedge at 0x17a665cc3a0>,
#   <matplotlib.patches.Wedge at 0x17a665cca30>,
#   <matplotlib.patches.Wedge at 0x17a665cd0c0>,
#   <matplotlib.patches.Wedge at 0x17a665cd750>,
#   <matplotlib.patches.Wedge at 0x17a665cdde0>,
#   <matplotlib.patches.Wedge at 0x17a665ce470>,
#   <matplotlib.patches.Wedge at 0x17a665ceb00>,
#   <matplotlib.patches.Wedge at 0x17a665cf190>,
#   <matplotlib.patches.Wedge at 0x17a665cf820>,
#   <matplotlib.patches.Wedge at 0x17a665cfeb0>,
#   <matplotlib.patches.Wedge at 0x17a66604580>,
#   <matplotlib.patches.Wedge at 0x17a66604c10>,
#   <matplotlib.patches.Wedge at 0x17a666052a0>,
#   <matplotlib.patches.Wedge at 0x17a66605930>,
#   <matplotlib.patches.Wedge at 0x17a66605fc0>,
#   <matplotlib.patches.Wedge at 0x17a66606650>,
#   <matplotlib.patches.Wedge at 0x17a66606ce0>,
#   <matplotlib.patches.Wedge at 0x17a66607370>,
#   <matplotlib.patches.Wedge at 0x17a66607a00>,
#   <matplotlib.patches.Wedge at 0x17a6663c0d0>,
#   <matplotlib.patches.Wedge at 0x17a6663c760>,
#   <matplotlib.patches.Wedge at 0x17a6663cdf0>,
#   <matplotlib.patches.Wedge at 0x17a6663d480>,
#   <matplotlib.patches.Wedge at 0x17a6663db10>,
#   <matplotlib.patches.Wedge at 0x17a6663e1a0>,
#   <matplotlib.patches.Wedge at 0x17a6663e830>,
#   <matplotlib.patches.Wedge at 0x17a6663eec0>,
#   <matplotlib.patches.Wedge at 0x17a6663f550>,
#   <matplotlib.patches.Wedge at 0x17a6663fbe0>,
#   <matplotlib.patches.Wedge at 0x17a666782b0>,
#   <matplotlib.patches.Wedge at 0x17a66678940>,
#   <matplotlib.patches.Wedge at 0x17a66678fd0>,
#   <matplotlib.patches.Wedge at 0x17a66679660>,
#   <matplotlib.patches.Wedge at 0x17a66679cf0>,
#   <matplotlib.patches.Wedge at 0x17a6667a380>,
#   <matplotlib.patches.Wedge at 0x17a6667aa10>,
#   <matplotlib.patches.Wedge at 0x17a6667b0a0>,
#   <matplotlib.patches.Wedge at 0x17a6667b730>,
#   <matplotlib.patches.Wedge at 0x17a6667bdc0>,
#   <matplotlib.patches.Wedge at 0x17a666b4490>,
#   <matplotlib.patches.Wedge at 0x17a666b4b20>,
#   <matplotlib.patches.Wedge at 0x17a666b51b0>,
#   <matplotlib.patches.Wedge at 0x17a666b5840>,
#   <matplotlib.patches.Wedge at 0x17a666b5ed0>,
#   <matplotlib.patches.Wedge at 0x17a666b6560>,
#   <matplotlib.patches.Wedge at 0x17a666b6bf0>,
#   <matplotlib.patches.Wedge at 0x17a666b7280>,
#   <matplotlib.patches.Wedge at 0x17a666b7910>,
#   <matplotlib.patches.Wedge at 0x17a666b7fa0>,
#   <matplotlib.patches.Wedge at 0x17a666f0670>,
#   <matplotlib.patches.Wedge at 0x17a666f0d00>,
#   <matplotlib.patches.Wedge at 0x17a666f1390>,
#   <matplotlib.patches.Wedge at 0x17a666f1a20>,
#   <matplotlib.patches.Wedge at 0x17a666f20b0>,
#   <matplotlib.patches.Wedge at 0x17a666f2740>,
#   <matplotlib.patches.Wedge at 0x17a666f2dd0>,
#   <matplotlib.patches.Wedge at 0x17a666f3460>,
#   <matplotlib.patches.Wedge at 0x17a666f3af0>,
#   <matplotlib.patches.Wedge at 0x17a667281c0>,
#   <matplotlib.patches.Wedge at 0x17a66728850>,
#   <matplotlib.patches.Wedge at 0x17a66728ee0>,
#   <matplotlib.patches.Wedge at 0x17a66729570>,
#   <matplotlib.patches.Wedge at 0x17a66729c00>,
#   <matplotlib.patches.Wedge at 0x17a6672a290>,
#   <matplotlib.patches.Wedge at 0x17a6672a920>,
#   <matplotlib.patches.Wedge at 0x17a6672afb0>,
#   <matplotlib.patches.Wedge at 0x17a6672b640>,
#   <matplotlib.patches.Wedge at 0x17a6672bcd0>,
#   <matplotlib.patches.Wedge at 0x17a6676c3a0>,
#   <matplotlib.patches.Wedge at 0x17a6676ca30>,
#   <matplotlib.patches.Wedge at 0x17a6676d0c0>,
#   <matplotlib.patches.Wedge at 0x17a6676d750>,
#   <matplotlib.patches.Wedge at 0x17a6676dde0>,
#   <matplotlib.patches.Wedge at 0x17a6676e470>,
#   <matplotlib.patches.Wedge at 0x17a6676eb00>,
#   <matplotlib.patches.Wedge at 0x17a6676f190>,
#   <matplotlib.patches.Wedge at 0x17a6676f820>,
#   <matplotlib.patches.Wedge at 0x17a6676feb0>,
#   <matplotlib.patches.Wedge at 0x17a667a0580>,
#   <matplotlib.patches.Wedge at 0x17a667a0c10>,
#   <matplotlib.patches.Wedge at 0x17a667a12a0>,
#   <matplotlib.patches.Wedge at 0x17a667a1930>,
#   <matplotlib.patches.Wedge at 0x17a667a1fc0>,
#   <matplotlib.patches.Wedge at 0x17a667a2650>,
#   <matplotlib.patches.Wedge at 0x17a667a2ce0>,
#   <matplotlib.patches.Wedge at 0x17a667a3370>,
#   <matplotlib.patches.Wedge at 0x17a667a3a00>,
#   <matplotlib.patches.Wedge at 0x17a667dc100>,
#   <matplotlib.patches.Wedge at 0x17a667dc790>,
#   <matplotlib.patches.Wedge at 0x17a667dce20>,
#   <matplotlib.patches.Wedge at 0x17a667dd4b0>,
#   <matplotlib.patches.Wedge at 0x17a667ddb40>,
#   <matplotlib.patches.Wedge at 0x17a667de1d0>,
#   <matplotlib.patches.Wedge at 0x17a667de860>,
#   <matplotlib.patches.Wedge at 0x17a667deef0>,
#   <matplotlib.patches.Wedge at 0x17a667df580>,
#   <matplotlib.patches.Wedge at 0x17a667dfc10>,
#   <matplotlib.patches.Wedge at 0x17a668182e0>,
#   <matplotlib.patches.Wedge at 0x17a66818970>,
#   <matplotlib.patches.Wedge at 0x17a66819000>,
#   <matplotlib.patches.Wedge at 0x17a66819690>,
#   <matplotlib.patches.Wedge at 0x17a66819d20>,
#   <matplotlib.patches.Wedge at 0x17a6681a3b0>,
#   <matplotlib.patches.Wedge at 0x17a6681aa40>,
#   <matplotlib.patches.Wedge at 0x17a6681b0d0>,
#   <matplotlib.patches.Wedge at 0x17a6681b760>,
#   <matplotlib.patches.Wedge at 0x17a6681bdf0>,
#   <matplotlib.patches.Wedge at 0x17a668544c0>,
#   <matplotlib.patches.Wedge at 0x17a66854b50>,
#   <matplotlib.patches.Wedge at 0x17a668551e0>,
#   <matplotlib.patches.Wedge at 0x17a66855870>,
#   <matplotlib.patches.Wedge at 0x17a66855f00>,
#   <matplotlib.patches.Wedge at 0x17a66856590>,
#   <matplotlib.patches.Wedge at 0x17a66856c20>,
#   <matplotlib.patches.Wedge at 0x17a668572b0>,
#   <matplotlib.patches.Wedge at 0x17a66857940>,
#   <matplotlib.patches.Wedge at 0x17a66857fd0>,
#   <matplotlib.patches.Wedge at 0x17a668906a0>,
#   <matplotlib.patches.Wedge at 0x17a66890d30>,
#   <matplotlib.patches.Wedge at 0x17a668913c0>,
#   <matplotlib.patches.Wedge at 0x17a66891a50>,
#   <matplotlib.patches.Wedge at 0x17a668920e0>,
#   <matplotlib.patches.Wedge at 0x17a66892770>,
#   <matplotlib.patches.Wedge at 0x17a66892e00>,
#   <matplotlib.patches.Wedge at 0x17a66893490>,
#   <matplotlib.patches.Wedge at 0x17a66893b20>,
#   <matplotlib.patches.Wedge at 0x17a668c41f0>,
#   <matplotlib.patches.Wedge at 0x17a668c4880>,
#   <matplotlib.patches.Wedge at 0x17a668c4f10>,
#   <matplotlib.patches.Wedge at 0x17a668c55a0>,
#   <matplotlib.patches.Wedge at 0x17a668c5c30>,
#   <matplotlib.patches.Wedge at 0x17a668c62c0>,
#   <matplotlib.patches.Wedge at 0x17a668c6950>,
#   <matplotlib.patches.Wedge at 0x17a668c6fe0>,
#   <matplotlib.patches.Wedge at 0x17a668c7670>,
#   <matplotlib.patches.Wedge at 0x17a668c7d00>,
#   <matplotlib.patches.Wedge at 0x17a669003d0>,
#   <matplotlib.patches.Wedge at 0x17a66900a60>,
#   <matplotlib.patches.Wedge at 0x17a669010f0>,
#   <matplotlib.patches.Wedge at 0x17a66901780>,
#   <matplotlib.patches.Wedge at 0x17a66901e10>,
#   <matplotlib.patches.Wedge at 0x17a669024a0>,
#   <matplotlib.patches.Wedge at 0x17a66902b30>,
#   <matplotlib.patches.Wedge at 0x17a669031c0>,
#   <matplotlib.patches.Wedge at 0x17a66903850>,
#   <matplotlib.patches.Wedge at 0x17a66903ee0>,
#   <matplotlib.patches.Wedge at 0x17a669405b0>,
#   <matplotlib.patches.Wedge at 0x17a66940c40>,
#   <matplotlib.patches.Wedge at 0x17a669412d0>,
#   <matplotlib.patches.Wedge at 0x17a66941960>,
#   <matplotlib.patches.Wedge at 0x17a66941ff0>,
#   <matplotlib.patches.Wedge at 0x17a66942680>,
#   <matplotlib.patches.Wedge at 0x17a66942d10>,
#   <matplotlib.patches.Wedge at 0x17a669433a0>,
#   <matplotlib.patches.Wedge at 0x17a66943a30>,
#   <matplotlib.patches.Wedge at 0x17a6697c100>,
#   <matplotlib.patches.Wedge at 0x17a6697c790>,
#   <matplotlib.patches.Wedge at 0x17a6697ce20>,
#   <matplotlib.patches.Wedge at 0x17a6697d4b0>,
#   <matplotlib.patches.Wedge at 0x17a6697db40>,
#   <matplotlib.patches.Wedge at 0x17a6697e1d0>,
#   <matplotlib.patches.Wedge at 0x17a6697e860>,
#   <matplotlib.patches.Wedge at 0x17a6697eef0>,
#   <matplotlib.patches.Wedge at 0x17a6697f580>,
#   <matplotlib.patches.Wedge at 0x17a6697fc10>,
#   <matplotlib.patches.Wedge at 0x17a669b82e0>,
#   <matplotlib.patches.Wedge at 0x17a669b8970>,
#   <matplotlib.patches.Wedge at 0x17a669b9000>,
#   <matplotlib.patches.Wedge at 0x17a669b9690>,
#   <matplotlib.patches.Wedge at 0x17a669b9d20>,
#   <matplotlib.patches.Wedge at 0x17a669ba3b0>,
#   <matplotlib.patches.Wedge at 0x17a669baa40>,
#   <matplotlib.patches.Wedge at 0x17a669bb0d0>,
#   <matplotlib.patches.Wedge at 0x17a669bb760>,
#   <matplotlib.patches.Wedge at 0x17a669bbdf0>,
#   <matplotlib.patches.Wedge at 0x17a669f04c0>,
#   <matplotlib.patches.Wedge at 0x17a669f0b50>,
#   <matplotlib.patches.Wedge at 0x17a669f11e0>,
#   <matplotlib.patches.Wedge at 0x17a669f1870>,
#   <matplotlib.patches.Wedge at 0x17a669f1f00>,
#   <matplotlib.patches.Wedge at 0x17a669f2590>,
#   <matplotlib.patches.Wedge at 0x17a669f2c20>,
#   <matplotlib.patches.Wedge at 0x17a669f32b0>,
#   <matplotlib.patches.Wedge at 0x17a669f3940>,
#   <matplotlib.patches.Wedge at 0x17a669f3fd0>,
#   <matplotlib.patches.Wedge at 0x17a66a286a0>,
#   <matplotlib.patches.Wedge at 0x17a66a28d30>,
#   <matplotlib.patches.Wedge at 0x17a66a293c0>,
#   <matplotlib.patches.Wedge at 0x17a66a29a50>,
#   <matplotlib.patches.Wedge at 0x17a66a2a0e0>,
#   <matplotlib.patches.Wedge at 0x17a66a2a770>,
#   <matplotlib.patches.Wedge at 0x17a66a2ae00>,
#   <matplotlib.patches.Wedge at 0x17a66a2b490>,
#   <matplotlib.patches.Wedge at 0x17a66a2bb20>,
#   <matplotlib.patches.Wedge at 0x17a66a6c1f0>,
#   <matplotlib.patches.Wedge at 0x17a66a6c880>,
#   <matplotlib.patches.Wedge at 0x17a66a6cf10>,
#   <matplotlib.patches.Wedge at 0x17a66a6d5a0>,
#   <matplotlib.patches.Wedge at 0x17a66a6dc30>,
#   <matplotlib.patches.Wedge at 0x17a66a6e2c0>,
#   <matplotlib.patches.Wedge at 0x17a66a6e950>,
#   <matplotlib.patches.Wedge at 0x17a66a6efe0>,
#   <matplotlib.patches.Wedge at 0x17a66a6f670>,
#   <matplotlib.patches.Wedge at 0x17a66a6fd00>,
#   <matplotlib.patches.Wedge at 0x17a66aa43d0>,
#   <matplotlib.patches.Wedge at 0x17a66aa4a60>,
#   <matplotlib.patches.Wedge at 0x17a66aa50f0>,
#   <matplotlib.patches.Wedge at 0x17a66aa5780>,
#   <matplotlib.patches.Wedge at 0x17a66aa5e10>,
#   <matplotlib.patches.Wedge at 0x17a66aa64a0>,
#   <matplotlib.patches.Wedge at 0x17a66aa6b30>,
#   <matplotlib.patches.Wedge at 0x17a66aa71c0>,
#   <matplotlib.patches.Wedge at 0x17a66aa7850>,
#   <matplotlib.patches.Wedge at 0x17a66aa7ee0>,
#   <matplotlib.patches.Wedge at 0x17a66ae05b0>,
#   <matplotlib.patches.Wedge at 0x17a66ae0c40>,
#   <matplotlib.patches.Wedge at 0x17a66ae12d0>,
#   <matplotlib.patches.Wedge at 0x17a66ae1960>,
#   <matplotlib.patches.Wedge at 0x17a66ae1ff0>,
#   <matplotlib.patches.Wedge at 0x17a66ae2680>,
#   <matplotlib.patches.Wedge at 0x17a66ae2d10>,
#   <matplotlib.patches.Wedge at 0x17a66ae33a0>,
#   <matplotlib.patches.Wedge at 0x17a66ae3a30>,
#   <matplotlib.patches.Wedge at 0x17a66b10100>,
#   <matplotlib.patches.Wedge at 0x17a66b10790>,
#   <matplotlib.patches.Wedge at 0x17a66b10e20>,
#   <matplotlib.patches.Wedge at 0x17a66b114b0>,
#   <matplotlib.patches.Wedge at 0x17a66b11b40>,
#   <matplotlib.patches.Wedge at 0x17a66b121d0>,
#   <matplotlib.patches.Wedge at 0x17a66b12860>,
#   <matplotlib.patches.Wedge at 0x17a66b12ef0>,
#   <matplotlib.patches.Wedge at 0x17a66b13580>,
#   <matplotlib.patches.Wedge at 0x17a66b13c10>,
#   <matplotlib.patches.Wedge at 0x17a66b502e0>,
#   <matplotlib.patches.Wedge at 0x17a66b50970>,
#   <matplotlib.patches.Wedge at 0x17a66b51000>,
#   <matplotlib.patches.Wedge at 0x17a66b51690>,
#   <matplotlib.patches.Wedge at 0x17a66b51d20>,
#   <matplotlib.patches.Wedge at 0x17a66b523b0>,
#   <matplotlib.patches.Wedge at 0x17a66b52a40>,
#   <matplotlib.patches.Wedge at 0x17a66b530d0>,
#   <matplotlib.patches.Wedge at 0x17a66b53760>,
#   <matplotlib.patches.Wedge at 0x17a66b53df0>,
#   <matplotlib.patches.Wedge at 0x17a66b904c0>,
#   <matplotlib.patches.Wedge at 0x17a66b90b50>,
#   <matplotlib.patches.Wedge at 0x17a66b911e0>,
#   <matplotlib.patches.Wedge at 0x17a66b91870>,
#   <matplotlib.patches.Wedge at 0x17a66b91f00>,
#   <matplotlib.patches.Wedge at 0x17a66b92590>,
#   <matplotlib.patches.Wedge at 0x17a66b92c20>,
#   <matplotlib.patches.Wedge at 0x17a66b932b0>,
#   <matplotlib.patches.Wedge at 0x17a66b93940>,
#   <matplotlib.patches.Wedge at 0x17a66b93fd0>,
#   <matplotlib.patches.Wedge at 0x17a66bcc6a0>,
#   <matplotlib.patches.Wedge at 0x17a66bccd30>,
#   <matplotlib.patches.Wedge at 0x17a66bcd3c0>,
#   <matplotlib.patches.Wedge at 0x17a66bcda50>,
#   <matplotlib.patches.Wedge at 0x17a66bce0e0>,
#   <matplotlib.patches.Wedge at 0x17a66bce770>,
#   <matplotlib.patches.Wedge at 0x17a66bcee00>,
#   <matplotlib.patches.Wedge at 0x17a66bcf490>,
#   <matplotlib.patches.Wedge at 0x17a66bcfb20>,
#   <matplotlib.patches.Wedge at 0x17a66c081f0>,
#   <matplotlib.patches.Wedge at 0x17a66c08880>,
#   <matplotlib.patches.Wedge at 0x17a66c08f10>,
#   <matplotlib.patches.Wedge at 0x17a66c095a0>,
#   <matplotlib.patches.Wedge at 0x17a66c09c30>,
#   <matplotlib.patches.Wedge at 0x17a66c0a2c0>,
#   <matplotlib.patches.Wedge at 0x17a66c0a950>,
#   <matplotlib.patches.Wedge at 0x17a66c0afe0>,
#   <matplotlib.patches.Wedge at 0x17a66c0b670>,
#   <matplotlib.patches.Wedge at 0x17a66c0bd00>,
#   <matplotlib.patches.Wedge at 0x17a66c403d0>,
#   <matplotlib.patches.Wedge at 0x17a66c40a60>,
#   <matplotlib.patches.Wedge at 0x17a66c410f0>,
#   <matplotlib.patches.Wedge at 0x17a66c41780>,
#   <matplotlib.patches.Wedge at 0x17a66c41e10>,
#   <matplotlib.patches.Wedge at 0x17a66c424a0>,
#   <matplotlib.patches.Wedge at 0x17a66c42b30>,
#   <matplotlib.patches.Wedge at 0x17a66c431c0>,
#   <matplotlib.patches.Wedge at 0x17a66c43850>,
#   <matplotlib.patches.Wedge at 0x17a66c43ee0>,
#   <matplotlib.patches.Wedge at 0x17a66c785b0>,
#   <matplotlib.patches.Wedge at 0x17a66c78c40>,
#   <matplotlib.patches.Wedge at 0x17a66c792d0>,
#   <matplotlib.patches.Wedge at 0x17a66c79960>,
#   <matplotlib.patches.Wedge at 0x17a66c79ff0>,
#   <matplotlib.patches.Wedge at 0x17a66c7a680>,
#   <matplotlib.patches.Wedge at 0x17a66c7ad10>,
#   <matplotlib.patches.Wedge at 0x17a66c7b3a0>,
#   <matplotlib.patches.Wedge at 0x17a66c7ba30>,
#   <matplotlib.patches.Wedge at 0x17a66cb8100>,
#   <matplotlib.patches.Wedge at 0x17a66cb8790>,
#   <matplotlib.patches.Wedge at 0x17a66cb8e20>,
#   <matplotlib.patches.Wedge at 0x17a66cb94b0>,
#   <matplotlib.patches.Wedge at 0x17a66cb9b40>,
#   <matplotlib.patches.Wedge at 0x17a66cba1d0>,
#   <matplotlib.patches.Wedge at 0x17a66cba860>,
#   <matplotlib.patches.Wedge at 0x17a66cbaef0>,
#   <matplotlib.patches.Wedge at 0x17a66cbb580>,
#   <matplotlib.patches.Wedge at 0x17a66cbbc10>,
#   <matplotlib.patches.Wedge at 0x17a66cf42e0>,
#   <matplotlib.patches.Wedge at 0x17a66cf4970>,
#   <matplotlib.patches.Wedge at 0x17a66cf5000>,
#   <matplotlib.patches.Wedge at 0x17a66cf5690>,
#   <matplotlib.patches.Wedge at 0x17a66cf5d20>,
#   <matplotlib.patches.Wedge at 0x17a66cf63b0>,
#   <matplotlib.patches.Wedge at 0x17a66cf6a40>,
#   <matplotlib.patches.Wedge at 0x17a66cf70d0>,
#   <matplotlib.patches.Wedge at 0x17a66cf7760>,
#   <matplotlib.patches.Wedge at 0x17a66cf7df0>,
#   <matplotlib.patches.Wedge at 0x17a66d304c0>,
#   <matplotlib.patches.Wedge at 0x17a66d30b50>,
#   <matplotlib.patches.Wedge at 0x17a66d311e0>,
#   <matplotlib.patches.Wedge at 0x17a66d31870>,
#   <matplotlib.patches.Wedge at 0x17a66d31f00>,
#   <matplotlib.patches.Wedge at 0x17a66d32590>,
#   <matplotlib.patches.Wedge at 0x17a66d32c20>,
#   <matplotlib.patches.Wedge at 0x17a66d332b0>,
#   <matplotlib.patches.Wedge at 0x17a66d33940>,
#   <matplotlib.patches.Wedge at 0x17a66d33fd0>,
#   <matplotlib.patches.Wedge at 0x17a66d686a0>,
#   <matplotlib.patches.Wedge at 0x17a66d68d30>,
#   <matplotlib.patches.Wedge at 0x17a66d693c0>,
#   <matplotlib.patches.Wedge at 0x17a66d69a50>,
#   <matplotlib.patches.Wedge at 0x17a66d6a0e0>,
#   <matplotlib.patches.Wedge at 0x17a66d6a770>,
#   <matplotlib.patches.Wedge at 0x17a66d6ae00>,
#   <matplotlib.patches.Wedge at 0x17a66d6b490>,
#   <matplotlib.patches.Wedge at 0x17a66d6bb20>,
#   <matplotlib.patches.Wedge at 0x17a66da01f0>,
#   <matplotlib.patches.Wedge at 0x17a66da0880>,
#   <matplotlib.patches.Wedge at 0x17a66da0f10>,
#   <matplotlib.patches.Wedge at 0x17a66da15a0>,
#   <matplotlib.patches.Wedge at 0x17a66da1c30>,
#   <matplotlib.patches.Wedge at 0x17a66da22c0>,
#   <matplotlib.patches.Wedge at 0x17a66da2950>,
#   <matplotlib.patches.Wedge at 0x17a66da2fe0>,
#   <matplotlib.patches.Wedge at 0x17a66da3670>,
#   <matplotlib.patches.Wedge at 0x17a66da3d00>,
#   <matplotlib.patches.Wedge at 0x17a66ddc3d0>,
#   <matplotlib.patches.Wedge at 0x17a66ddca60>,
#   <matplotlib.patches.Wedge at 0x17a66ddd0f0>,
#   <matplotlib.patches.Wedge at 0x17a66ddd780>,
#   <matplotlib.patches.Wedge at 0x17a66ddde10>,
#   <matplotlib.patches.Wedge at 0x17a66dde4a0>,
#   <matplotlib.patches.Wedge at 0x17a66ddeb30>,
#   <matplotlib.patches.Wedge at 0x17a66ddf1c0>,
#   <matplotlib.patches.Wedge at 0x17a66ddf850>,
#   <matplotlib.patches.Wedge at 0x17a66ddfee0>,
#   <matplotlib.patches.Wedge at 0x17a66e205b0>,
#   <matplotlib.patches.Wedge at 0x17a66e20c40>,
#   <matplotlib.patches.Wedge at 0x17a66e212d0>,
#   <matplotlib.patches.Wedge at 0x17a66e21960>,
#   <matplotlib.patches.Wedge at 0x17a66e21ff0>,
#   <matplotlib.patches.Wedge at 0x17a66e22680>,
#   <matplotlib.patches.Wedge at 0x17a66e22d10>,
#   <matplotlib.patches.Wedge at 0x17a66e233a0>,
#   <matplotlib.patches.Wedge at 0x17a66e23a30>,
#   <matplotlib.patches.Wedge at 0x17a66e58100>,
#   <matplotlib.patches.Wedge at 0x17a66e58790>,
#   <matplotlib.patches.Wedge at 0x17a66e58e20>,
#   <matplotlib.patches.Wedge at 0x17a66e594b0>,
#   <matplotlib.patches.Wedge at 0x17a66e59b40>,
#   <matplotlib.patches.Wedge at 0x17a66e5a1d0>,
#   <matplotlib.patches.Wedge at 0x17a66e5a860>,
#   <matplotlib.patches.Wedge at 0x17a66e5aef0>,
#   <matplotlib.patches.Wedge at 0x17a66e5b580>,
#   <matplotlib.patches.Wedge at 0x17a66e5bc10>,
#   <matplotlib.patches.Wedge at 0x17a66e942e0>,
#   <matplotlib.patches.Wedge at 0x17a66e94970>,
#   <matplotlib.patches.Wedge at 0x17a66e95000>,
#   <matplotlib.patches.Wedge at 0x17a66e95690>,
#   <matplotlib.patches.Wedge at 0x17a66e95d20>,
#   <matplotlib.patches.Wedge at 0x17a66e963b0>,
#   <matplotlib.patches.Wedge at 0x17a66e96a40>,
#   <matplotlib.patches.Wedge at 0x17a66e970d0>,
#   <matplotlib.patches.Wedge at 0x17a66e97760>,
#   <matplotlib.patches.Wedge at 0x17a66e97df0>,
#   <matplotlib.patches.Wedge at 0x17a66ecc4c0>,
#   <matplotlib.patches.Wedge at 0x17a66eccb50>,
#   <matplotlib.patches.Wedge at 0x17a66ecd1e0>,
#   <matplotlib.patches.Wedge at 0x17a66ecd870>,
#   <matplotlib.patches.Wedge at 0x17a66ecdf00>,
#   <matplotlib.patches.Wedge at 0x17a66ece590>,
#   <matplotlib.patches.Wedge at 0x17a66ecec20>,
#   <matplotlib.patches.Wedge at 0x17a66ecf2b0>,
#   <matplotlib.patches.Wedge at 0x17a66ecf940>,
#   <matplotlib.patches.Wedge at 0x17a66ecffd0>,
#   <matplotlib.patches.Wedge at 0x17a66f0c6a0>,
#   <matplotlib.patches.Wedge at 0x17a66f0cd30>,
#   <matplotlib.patches.Wedge at 0x17a66f0d3c0>,
#   <matplotlib.patches.Wedge at 0x17a66f0da50>,
#   <matplotlib.patches.Wedge at 0x17a66f0e0e0>,
#   <matplotlib.patches.Wedge at 0x17a66f0e770>,
#   <matplotlib.patches.Wedge at 0x17a66f0ee00>,
#   <matplotlib.patches.Wedge at 0x17a66f0f490>,
#   <matplotlib.patches.Wedge at 0x17a66f0fb20>,
#   <matplotlib.patches.Wedge at 0x17a66f401f0>,
#   <matplotlib.patches.Wedge at 0x17a66f40880>,
#   <matplotlib.patches.Wedge at 0x17a66f40f10>,
#   <matplotlib.patches.Wedge at 0x17a66f415a0>,
#   <matplotlib.patches.Wedge at 0x17a66f41c30>,
#   <matplotlib.patches.Wedge at 0x17a66f422c0>,
#   <matplotlib.patches.Wedge at 0x17a66f42950>,
#   <matplotlib.patches.Wedge at 0x17a66f42fe0>,
#   <matplotlib.patches.Wedge at 0x17a66f43670>,
#   <matplotlib.patches.Wedge at 0x17a66f43d00>,
#   <matplotlib.patches.Wedge at 0x17a66f803d0>,
#   <matplotlib.patches.Wedge at 0x17a66f80a60>,
#   <matplotlib.patches.Wedge at 0x17a66f810f0>,
#   <matplotlib.patches.Wedge at 0x17a66f81780>,
#   <matplotlib.patches.Wedge at 0x17a66f81e10>,
#   <matplotlib.patches.Wedge at 0x17a66f824a0>,
#   <matplotlib.patches.Wedge at 0x17a66f82b30>,
#   <matplotlib.patches.Wedge at 0x17a66f831c0>,
#   <matplotlib.patches.Wedge at 0x17a66f83850>,
#   <matplotlib.patches.Wedge at 0x17a66f83ee0>,
#   <matplotlib.patches.Wedge at 0x17a66fb85b0>,
#   <matplotlib.patches.Wedge at 0x17a66fb8c40>,
#   <matplotlib.patches.Wedge at 0x17a66fb92d0>,
#   <matplotlib.patches.Wedge at 0x17a66fb9960>,
#   <matplotlib.patches.Wedge at 0x17a66fb9ff0>,
#   <matplotlib.patches.Wedge at 0x17a66fba680>,
#   <matplotlib.patches.Wedge at 0x17a66fbad10>,
#   <matplotlib.patches.Wedge at 0x17a66fbb3a0>,
#   <matplotlib.patches.Wedge at 0x17a66fbba30>,
#   <matplotlib.patches.Wedge at 0x17a66ff4100>,
#   <matplotlib.patches.Wedge at 0x17a66ff4790>,
#   <matplotlib.patches.Wedge at 0x17a66ff4e20>,
#   <matplotlib.patches.Wedge at 0x17a66ff54b0>,
#   <matplotlib.patches.Wedge at 0x17a66ff5b40>,
#   <matplotlib.patches.Wedge at 0x17a66ff61d0>,
#   <matplotlib.patches.Wedge at 0x17a66ff6860>,
#   <matplotlib.patches.Wedge at 0x17a66ff6ef0>,
#   <matplotlib.patches.Wedge at 0x17a66ff7580>,
#   <matplotlib.patches.Wedge at 0x17a66ff7c10>,
#   <matplotlib.patches.Wedge at 0x17a670342e0>,
#   <matplotlib.patches.Wedge at 0x17a67034970>,
#   <matplotlib.patches.Wedge at 0x17a67035000>,
#   <matplotlib.patches.Wedge at 0x17a67035690>,
#   <matplotlib.patches.Wedge at 0x17a67035d20>,
#   <matplotlib.patches.Wedge at 0x17a670363b0>,
#   <matplotlib.patches.Wedge at 0x17a67036a40>,
#   <matplotlib.patches.Wedge at 0x17a670370d0>,
#   <matplotlib.patches.Wedge at 0x17a67037760>,
#   <matplotlib.patches.Wedge at 0x17a67037df0>,
#   <matplotlib.patches.Wedge at 0x17a670684c0>,
#   <matplotlib.patches.Wedge at 0x17a67068b50>,
#   <matplotlib.patches.Wedge at 0x17a670691e0>,
#   <matplotlib.patches.Wedge at 0x17a67069870>,
#   <matplotlib.patches.Wedge at 0x17a67069f00>,
#   <matplotlib.patches.Wedge at 0x17a6706a590>,
#   <matplotlib.patches.Wedge at 0x17a6706ac20>,
#   <matplotlib.patches.Wedge at 0x17a6706b2b0>,
#   <matplotlib.patches.Wedge at 0x17a6706b940>,
#   <matplotlib.patches.Wedge at 0x17a6706bfd0>,
#   <matplotlib.patches.Wedge at 0x17a670ac6a0>,
#   <matplotlib.patches.Wedge at 0x17a670acd30>,
#   <matplotlib.patches.Wedge at 0x17a670ad3c0>,
#   <matplotlib.patches.Wedge at 0x17a670ada50>,
#   <matplotlib.patches.Wedge at 0x17a670ae0e0>,
#   <matplotlib.patches.Wedge at 0x17a670ae770>,
#   <matplotlib.patches.Wedge at 0x17a670aee00>,
#   <matplotlib.patches.Wedge at 0x17a670af490>,
#   <matplotlib.patches.Wedge at 0x17a670afb20>,
#   <matplotlib.patches.Wedge at 0x17a670e41f0>,
#   <matplotlib.patches.Wedge at 0x17a670e4880>,
#   <matplotlib.patches.Wedge at 0x17a670e4f10>,
#   <matplotlib.patches.Wedge at 0x17a670e55a0>,
#   <matplotlib.patches.Wedge at 0x17a670e5c30>,
#   <matplotlib.patches.Wedge at 0x17a670e62c0>,
#   <matplotlib.patches.Wedge at 0x17a670e6950>,
#   <matplotlib.patches.Wedge at 0x17a670e6fe0>,
#   <matplotlib.patches.Wedge at 0x17a670e7670>,
#   <matplotlib.patches.Wedge at 0x17a670e7d00>,
#   <matplotlib.patches.Wedge at 0x17a671243d0>,
#   <matplotlib.patches.Wedge at 0x17a67124a60>,
#   <matplotlib.patches.Wedge at 0x17a671250f0>,
#   <matplotlib.patches.Wedge at 0x17a67125780>,
#   <matplotlib.patches.Wedge at 0x17a67125e10>,
#   <matplotlib.patches.Wedge at 0x17a671264a0>,
#   <matplotlib.patches.Wedge at 0x17a67126b30>,
#   <matplotlib.patches.Wedge at 0x17a671271c0>,
#   <matplotlib.patches.Wedge at 0x17a67127850>,
#   <matplotlib.patches.Wedge at 0x17a67127ee0>,
#   <matplotlib.patches.Wedge at 0x17a671585b0>,
#   <matplotlib.patches.Wedge at 0x17a67158c40>,
#   <matplotlib.patches.Wedge at 0x17a671592d0>,
#   <matplotlib.patches.Wedge at 0x17a67159960>,
#   <matplotlib.patches.Wedge at 0x17a67159ff0>,
#   <matplotlib.patches.Wedge at 0x17a6715a680>,
#   <matplotlib.patches.Wedge at 0x17a6715ad10>,
#   <matplotlib.patches.Wedge at 0x17a6715b3a0>,
#   <matplotlib.patches.Wedge at 0x17a6715ba30>,
#   <matplotlib.patches.Wedge at 0x17a67194100>,
#   <matplotlib.patches.Wedge at 0x17a67194790>,
#   <matplotlib.patches.Wedge at 0x17a67194e20>,
#   <matplotlib.patches.Wedge at 0x17a671954b0>,
#   <matplotlib.patches.Wedge at 0x17a67195b40>,
#   <matplotlib.patches.Wedge at 0x17a671961d0>,
#   <matplotlib.patches.Wedge at 0x17a67196860>,
#   <matplotlib.patches.Wedge at 0x17a67196ef0>,
#   <matplotlib.patches.Wedge at 0x17a67197580>,
#   <matplotlib.patches.Wedge at 0x17a67197c10>,
#   <matplotlib.patches.Wedge at 0x17a671c82e0>,
#   <matplotlib.patches.Wedge at 0x17a671c8970>,
#   <matplotlib.patches.Wedge at 0x17a671c9000>,
#   <matplotlib.patches.Wedge at 0x17a671c9690>,
#   <matplotlib.patches.Wedge at 0x17a671c9d20>,
#   <matplotlib.patches.Wedge at 0x17a671ca3b0>,
#   <matplotlib.patches.Wedge at 0x17a671caa40>,
#   <matplotlib.patches.Wedge at 0x17a671cb0d0>,
#   <matplotlib.patches.Wedge at 0x17a671cb760>,
#   <matplotlib.patches.Wedge at 0x17a671cbdf0>,
#   <matplotlib.patches.Wedge at 0x17a672104c0>,
#   <matplotlib.patches.Wedge at 0x17a67210b50>,
#   <matplotlib.patches.Wedge at 0x17a672111e0>,
#   <matplotlib.patches.Wedge at 0x17a67211870>,
#   <matplotlib.patches.Wedge at 0x17a67211f00>,
#   <matplotlib.patches.Wedge at 0x17a67212590>,
#   <matplotlib.patches.Wedge at 0x17a67212c20>,
#   <matplotlib.patches.Wedge at 0x17a672132b0>,
#   <matplotlib.patches.Wedge at 0x17a67213940>,
#   <matplotlib.patches.Wedge at 0x17a67213fd0>,
#   <matplotlib.patches.Wedge at 0x17a672446a0>,
#   <matplotlib.patches.Wedge at 0x17a67244d30>,
#   <matplotlib.patches.Wedge at 0x17a672453f0>,
#   <matplotlib.patches.Wedge at 0x17a67245a80>,
#   <matplotlib.patches.Wedge at 0x17a67246110>,
#   <matplotlib.patches.Wedge at 0x17a672467a0>,
#   <matplotlib.patches.Wedge at 0x17a67246e30>,
#   <matplotlib.patches.Wedge at 0x17a672474c0>,
#   <matplotlib.patches.Wedge at 0x17a67247b50>,
#   <matplotlib.patches.Wedge at 0x17a67280220>,
#   <matplotlib.patches.Wedge at 0x17a672808b0>,
#   <matplotlib.patches.Wedge at 0x17a67280f40>,
#   <matplotlib.patches.Wedge at 0x17a672815d0>,
#   <matplotlib.patches.Wedge at 0x17a67281c60>,
#   <matplotlib.patches.Wedge at 0x17a672822f0>,
#   <matplotlib.patches.Wedge at 0x17a67282980>,
#   <matplotlib.patches.Wedge at 0x17a67283010>,
#   <matplotlib.patches.Wedge at 0x17a672836a0>,
#   <matplotlib.patches.Wedge at 0x17a67283d30>,
#   <matplotlib.patches.Wedge at 0x17a672b8400>,
#   <matplotlib.patches.Wedge at 0x17a672b8a90>,
#   <matplotlib.patches.Wedge at 0x17a672b9120>,
#   <matplotlib.patches.Wedge at 0x17a672b97b0>,
#   <matplotlib.patches.Wedge at 0x17a672b9e40>,
#   <matplotlib.patches.Wedge at 0x17a672ba4d0>,
#   <matplotlib.patches.Wedge at 0x17a672bab60>,
#   <matplotlib.patches.Wedge at 0x17a672bb1f0>,
#   <matplotlib.patches.Wedge at 0x17a672bb880>,
#   <matplotlib.patches.Wedge at 0x17a672bbf10>,
#   <matplotlib.patches.Wedge at 0x17a672fc5e0>,
#   <matplotlib.patches.Wedge at 0x17a672fcc70>,
#   <matplotlib.patches.Wedge at 0x17a672fd300>,
#   <matplotlib.patches.Wedge at 0x17a672fd990>,
#   <matplotlib.patches.Wedge at 0x17a672fe020>,
#   <matplotlib.patches.Wedge at 0x17a672fe6b0>,
#   <matplotlib.patches.Wedge at 0x17a672fed40>,
#   <matplotlib.patches.Wedge at 0x17a672ff3d0>,
#   <matplotlib.patches.Wedge at 0x17a672ffa60>,
#   <matplotlib.patches.Wedge at 0x17a67338130>,
#   <matplotlib.patches.Wedge at 0x17a673387c0>,
#   <matplotlib.patches.Wedge at 0x17a67338e50>,
#   <matplotlib.patches.Wedge at 0x17a673394e0>,
#   <matplotlib.patches.Wedge at 0x17a67339b70>,
#   <matplotlib.patches.Wedge at 0x17a6733a200>,
#   <matplotlib.patches.Wedge at 0x17a6733a890>,
#   <matplotlib.patches.Wedge at 0x17a6733af20>,
#   <matplotlib.patches.Wedge at 0x17a6733b5b0>,
#   <matplotlib.patches.Wedge at 0x17a6733bc40>,
#   <matplotlib.patches.Wedge at 0x17a67370310>,
#   <matplotlib.patches.Wedge at 0x17a673709a0>,
#   ...],
#  [Text(1.0999979792882764, 0.002108450072665439, ''),
#   Text(1.0999818136390314, 0.0063253192320627365, ''),
#   Text(1.0999494825781129, 0.010542095434114664, ''),
#   Text(1.0999009865806604, 0.014758716708775535, ''),
#   Text(1.099836326359375, 0.018975121088276495, ''),
#   Text(1.0997979349524691, 0.021083222578260927, ''),
#   Text(1.0997979349524691, 0.021083222578260927, ''),
#   Text(1.0997979349524691, 0.021083222578260927, ''),
#   Text(1.0997555028645074, 0.02319124660803619, ''),
#   Text(1.0997090302513857, 0.025299185432677083, ''),
#   Text(1.0997090302513857, 0.025299185432677083, ''),
#   Text(1.0996585172838458, 0.02740703130757142, ''),
#   Text(1.099603964147473, 0.029514776488448524, ''),
#   Text(1.099545371042697, 0.03162241323140768, ''),
#   Text(1.0994160658038665, 0.03583733042998971, ''),
#   Text(1.0992706034676336, 0.04005172096059187, ''),
#   Text(1.0991918140467556, 0.042158699370390254, ''),
#   Text(1.0991918140467556, 0.042158699370390254, ''),
# ...
#   Text(0.023570289712232243, 0.5995368557835968, '0.06'),
#   Text(0.02242107047959286, 0.5995809333180543, '0.00'),
#   Text(0.02127176887146261, 0.5996228079793822, '0.06'),
#   Text(0.01897293541925107, 0.5996999480753495, '0.06'),
#   Text(0.01667382313941915, 0.5997682749378425, '0.06'),
#   Text(0.014374465819885645, 0.5998277875627245, '0.06'),
#   Text(0.012074897252170999, 0.5998784850753939, '0.06'),
#   Text(0.009775151230899644, 0.5999203667307962, '0.06'),
#   Text(0.00747526155330442, 0.5999534319134359, '0.06'),
#   Text(0.006325273405611277, 0.5999666581705555, '0.00'),
#   Text(0.006325273405611277, 0.5999666581705555, '0.00'),
#   Text(0.005175262018728813, 0.5999776801373844, '0.06'),
#   Text(0.0028751864281313095, 0.5999931110462882, '0.06'),
#   Text(0.0017251306749428846, 0.5999975199316697, '0.00'),
#   Text(0.000575068583587587, 0.5999997244133736, '0.06'),
#   Text(-0.0017250577122051767, 0.5999975201414499, '0.06'),
#   Text(-0.004025158656426136, 0.5999864982629114, '0.06'),
#   Text(-0.0051751890584037, 0.599977680766718, '0.00'),
#   Text(-0.006325200446626482, 0.5999666589397364, '0.06'),
#   Text(-0.00862514928122727, 0.5999380024634849, '0.06'),
#   Text(-0.010924971360015101, 0.5999005292552948, '0.06'),
#   Text(-0.01322463288463993, 0.5998542398658748, '0.06'),
#   Text(-0.014374392877788291, 0.5998277893107279, '0.00'),
#   Text(-0.015524100059110688, 0.5997991349754972, '0.06'),
#   Text(-0.016673750204558687, 0.5997682769654593, '0.00'),
#   Text(-0.01782333909029302, 0.5997352153939873, '0.06'),
#   Text(-0.02012231618840486, 0.5996624820607122, '0.06'),
#   Text(-0.022420997567514044, 0.5995809360445656, '0.06'),
#   Text(-0.02357021680551347, 0.5995368586498591, '0.00'),
#   Text(-0.02357021680551347, 0.5995368586498591, '0.00'),
#   Text(-0.0247193494460338, 0.5994905785439542, '0.06'),
#   Text(-0.027017338047220247, 0.5993914108867779, '0.06'),
#   Text(-0.029314929599667715, 0.5992834345304119, '0.06'),
#   Text(-0.03161209033780614, 0.5991666510616844, '0.06'),
#   Text(-0.03390878650239618, 0.5990410621968538, '0.06'),
#   Text(-0.036204984341026446, 0.5989066697815829, '0.06'),
#   Text(-0.03850065010860845, 0.5987634757909124, '0.06'),
#   Text(-0.040795750067873594, 0.5986114823292313, '0.06'),
#   Text(-0.04309025048986791, 0.5984506916302464, '0.06'),
#   Text(-0.04423726533648623, 0.5983669980501509, '0.00'),
#   Text(-0.045384117654448775, 0.5982811060569497, '0.06'),
#   Text(-0.047677317850779596, 0.5981027281015826, '0.06'),
#   Text(-0.04996981737782558, 0.5979155603856006, '0.06'),
#   Text(-0.05226158254484944, 0.5977196056596336, '0.06'),
#   Text(-0.05340717921793485, 0.5976183340627891, '0.00'),
#   Text(-0.054552579671905535, 0.5975148668034465, '0.06'),
#   Text(-0.056842775090335924, 0.5973013468258962, '0.06'),
#   Text(-0.05798756164056872, 0.5971912948921654, '0.00'),
#   Text(-0.05913213514326413, 0.5970790488648875, '0.06'),
#   Text(-0.06142062618609079, 0.5968479761873273, '0.06'),
#   Text(-0.06370821458698703, 0.5966081321890764, '0.06'),
#   Text(-0.06599486672738981, 0.596359520394899, '0.06'),
#   Text(-0.06713783119785376, 0.5962319277110615, '0.00'),
#   Text(-0.06713783119785376, 0.5962319277110615, '0.00'),
#   Text(-0.06828054900249492, 0.5961021444584124, '0.06'),
#   Text(-0.07056522782175186, 0.5958360081620313, '0.06'),
#   Text(-0.07284886960935646, 0.5955611154169141, '0.06'),
#   Text(-0.07399029112800434, 0.5954203866335055, '0.00'),
#   Text(-0.07399029112800434, 0.5954203866335055, '0.00'),
#   Text(-0.07513144080474544, 0.5952774702629043, '0.06'),
#   Text(-0.0774129078630884, 0.5949850768684715, '0.06'),
#   Text(-0.079693237255782, 0.5946839395306499, '0.06'),
#   Text(-0.0808329648543798, 0.5945300932609303, '0.00'),
#   Text(-0.0808329648543798, 0.5945300932609303, '0.00'),
#   Text(-0.08197239547094157, 0.5943740626749754, '0.06'),
#   Text(-0.08425034901389467, 0.5940554508554204, '0.06'),
#   Text(-0.0865270644076723, 0.5937281087543275, '0.06'),
#   Text(-0.08880250819350193, 0.5933920411823392, '0.06'),
#   Text(-0.08993974278266612, 0.5932207368831502, '0.00'),
#   Text(-0.09107664693129808, 0.5930472530783291, '0.06'),
#   Text(-0.09334944720015494, 0.5926937495093275, '0.06'),
#   Text(-0.09562087559883639, 0.5923315356704485, '0.06'),
#   Text(-0.09789089874626795, 0.5919606168848126, '0.06'),
#   Text(-0.10015948328202624, 0.5915809986034689, '0.06'),
#   Text(-0.10242659586683042, 0.5911926864053149, '0.06'),
#   Text(-0.10355958976500088, 0.5909952718657779, '0.00'),
#   Text(-0.10469220318303095, 0.5907956859970145, '0.06'),
#   Text(-0.1069562719351004, 0.5903900032129141, '0.06'),
#   Text(-0.10921876885012176, 0.5899756440149574, '0.06'),
#   Text(-0.11034941747725575, 0.5897652126587583, '0.00'),
#   Text(-0.11147966067827789, 0.5895526144925964, '0.06'),
#   Text(-0.11373891419334048, 0.5891209208627036, '0.06'),
#   Text(-0.11599649619315748, 0.5886805694694796, '0.06'),
#   Text(-0.11712465000588013, 0.5884571491289745, '0.00'),
#   Text(-0.11825237350014206, 0.58823156678436, '0.06'),
#   Text(-0.12050651296175915, 0.5877739194059204, '0.06'),
#   Text(-0.12163292064735803, 0.5875418560535015, '0.00'),
#   Text(-0.12275888145101374, 0.5873076340597796, '0.06'),
#   Text(-0.1250094458669366, 0.5868327175985004, '0.06'),
#   Text(-0.12613404121058228, 0.5865920248757965, '0.00'),
#   Text(-0.12725817313507184, 0.5863491770014895, '0.06'),
#   Text(-0.12950503020796186, 0.585857019374894, '0.06'),
#   Text(-0.13062774710136163, 0.585607711430803, '0.00'),
#   Text(-0.13062774710136163, 0.585607711430803, '0.00'),
#   Text(-0.13174998406563412, 0.5853562519514975, '0.06'),
#   Text(-0.13287173697765667, 0.5851026418608452, '0.00'),
#   Text(-0.1339930017160854, 0.5848468820906144, '0.06'),
#   Text(-0.1362340501957676, 0.5843289172779805, '0.06'),
#   Text(-0.13847309657007112, 0.583802365125644, '0.06'),
#   Text(-0.14071010793381003, 0.5832672333718529, '0.06'),
#   Text(-0.14182784021201145, 0.5829964525970943, '0.00'),
#   Text(-0.14182784021201145, 0.5829964525970943, '0.00'),
#   Text(-0.1429450514117046, 0.582723529880942, '0.06'),
#   Text(-0.14406173742823197, 0.5824484662261196, '0.00'),
#   Text(-0.14517789415886528, 0.5821712626432168, '0.06'),
#   Text(-0.14740860336127456, 0.5816104397748362, '0.06'),
#   Text(-0.1496371462362702, 0.5810410695176934, '0.06'),
#   Text(-0.1518634900330259, 0.5804631602392946, '0.06'),
#   Text(-0.1540876020330337, 0.5798767204326359, '0.06'),
#   Text(-0.15519881089367854, 0.5795803042695534, '0.00'),
#   Text(-0.15519881089367854, 0.5795803042695534, '0.00'),
#   Text(-0.15519881089367854, 0.5795803042695534, '0.00'),
#   Text(-0.15630944955058382, 0.5792817587160789, '0.06'),
#   Text(-0.1585289999332459, 0.5786782838332236, '0.06'),
#   Text(-0.160746220562348, 0.5780663046527802, '0.06'),
#   Text(-0.1629610788534569, 0.5774458301684386, '0.06'),
#   Text(-0.16406761194910824, 0.5771324100319759, '0.00'),
#   Text(-0.16517354225685593, 0.5768168694987367, '0.06'),
#   Text(-0.16738357825802438, 0.5761794318869251, '0.06'),
#   Text(-0.16959115437811448, 0.575533526700833, '0.06'),
#   Text(-0.170694009842987, 0.5752074017289087, '0.00'),
#   Text(-0.170694009842987, 0.5752074017289087, '0.00'),
#   Text(-0.171796238174429, 0.5748791634327294, '0.06'),
#   Text(-0.17289783532282996, 0.5745488130182497, '0.00'),
#   Text(-0.17289783532282996, 0.5745488130182497, '0.00'),
#   Text(-0.17399879724089848, 0.5742163516991837, '0.06'),
#   Text(-0.1761987992085565, 0.573545101240925, '0.06'),
#   Text(-0.17729783117529205, 0.5732063145679203, '0.00'),
#   Text(-0.17729783117529205, 0.5732063145679203, '0.00'),
#   Text(-0.17839621174601658, 0.5728654219226976, '0.06'),
#   Text(-0.17949393688525642, 0.5725224245577037, '0.00'),
#   Text(-0.18059100255994615, 0.5721773237331181, '0.06'),
#   Text(-0.18278313939554208, 0.5714808167845268, '0.06'),
#   Text(-0.18497259003700386, 0.5707759113128396, '0.06'),
#   Text(-0.18715932230800808, 0.570062617677398, '0.06'),
#   Text(-0.18934330407217997, 0.5693409463608163, '0.06'),
#   Text(-0.19152450323356715, 0.5686109079688283, '0.06'),
#   Text(-0.19261404931939996, 0.5682427544674756, '0.00'),
#   Text(-0.19370288773710992, 0.5678725132301303, '0.06'),
#   Text(-0.19587842556911353, 0.5671257729962246, '0.06'),
#   Text(-0.19805108475771765, 0.5663706982412591, '0.06'),
#   Text(-0.20022083337336713, 0.5656073000618665, '0.06'),
#   Text(-0.20130460625003102, 0.5652224831891597, '0.00'),
#   Text(-0.20130460625003102, 0.5652224831891597, '0.00'),
#   Text(-0.2023876395292804, 0.5648355896770015, '0.06'),
#   Text(-0.2045514713819189, 0.5640555784277751, '0.06'),
#   Text(-0.20563226200534354, 0.563662463556485, '0.00'),
#   Text(-0.2067122971314542, 0.5632672777772888, '0.06'),
#   Text(-0.20779157279217905, 0.5628700225421075, '0.00'),
#   Text(-0.20779157279217905, 0.5628700225421075, '0.00'),
#   Text(-0.20887008502223625, 0.5624706993104652, '0.06'),
#   Text(-0.21102480334325915, 0.5616658547338789, '0.06'),
#   Text(-0.21210100151774391, 0.561260336345951, '0.00'),
#   Text(-0.21317642042862803, 0.5608527558755835, '0.06'),
#   Text(-0.21532490465802354, 0.560031414684938, '0.06'),
#   Text(-0.21747022445716752, 0.5592018432324317, '0.06'),
#   Text(-0.21961234829828602, 0.5583640537095061, '0.06'),
#   Text(-0.22175124470057353, 0.5575180584283762, '0.06'),
#   Text(-0.22388688223065487, 0.5566638698218493, '0.06'),
#   Text(-0.22601922950304773, 0.5558015004431426, '0.06'),
#   Text(-0.22814825518062348, 0.5549309629656982, '0.06'),
#   Text(-0.22921151264183745, 0.5544926351832283, '0.00'),
#   Text(-0.22921151264183745, 0.5544926351832283, '0.00'),
#   Text(-0.23027392797506815, 0.5540522701829974, '0.06'),
#   Text(-0.23133549727697894, 0.5536098695829156, '0.00'),
#   Text(-0.23239621664734164, 0.5531654350083723, '0.06'),
#   Text(-0.23345608218905056, 0.5527189680922296, '0.00'),
#   Text(-0.23451509000813728, 0.5522704704748166, '0.06'),
#   Text(-0.2366305169183403, 0.5513673897347929, '0.06'),
#   Text(-0.23874246628948476, 0.5504562060600409, '0.06'),
#   Text(-0.24085090708421136, 0.549536932841381, '0.06'),
#   Text(-0.24295580831672267, 0.5486095835885186, '0.06'),
#   Text(-0.2440069219282972, 0.548142884703503, '0.00'),
#   Text(-0.2440069219282972, 0.548142884703503, '0.00'),
#   Text(-0.2450571390532394, 0.5476741719298449, '0.06'),
#   Text(-0.24715486841245385, 0.5467307116122366, '0.06'),
#   Text(-0.24924896556598525, 0.5457792165008541, '0.06'),
#   Text(-0.2502946424463339, 0.5453004602626536, '0.00'),
#   Text(-0.2502946424463339, 0.5453004602626536, '0.00'),
#   Text(-0.2502946424463339, 0.5453004602626536, '0.00'),
#   Text(-0.2502946424463339, 0.5453004602626536, '0.00'),
#   Text(-0.2513393997388311, 0.5448197005789384, '0.06'),
#   Text(-0.25342614020982124, 0.5438521779476037, '0.06'),
#   Text(-0.25550915631206766, 0.5428766628256324, '0.06'),
#   Text(-0.2565492581564633, 0.5423859125561507, '0.00'),
#   Text(-0.2565492581564633, 0.5423859125561507, '0.00'),
#   Text(-0.2575884174334161, 0.5418931695492647, '0.06'),
#   Text(-0.2586266303250325, 0.5413984356153229, '0.00'),
#   Text(-0.2586266303250325, 0.5413984356153229, '0.00'),
#   Text(-0.2586266303250325, 0.5413984356153229, '0.00'),
#   Text(-0.2586266303250325, 0.5413984356153229, '0.00'),
#   Text(-0.2596638930168963, 0.5409017125719883, '0.06'),
#   Text(-0.2617355525611699, 0.539902306464326, '0.06'),
#   Text(-0.26380336562097967, 0.5388949659136218, '0.06'),
#   Text(-0.2648358202205124, 0.5383883248438142, '0.00'),
#   Text(-0.26586730180759616, 0.537879705723825, '0.06'),
#   Text(-0.26792733078926556, 0.5368565408152717, '0.06'),
#   Text(-0.26895587061526055, 0.5363419987858373, '0.00'),
#   Text(-0.26998342229165384, 0.535825486224467, '0.06'),
#   Text(-0.2720355460982928, 0.5347865571038632, '0.06'),
#   Text(-0.2730601106889917, 0.5342641443616777, '0.00'),
#   Text(-0.2730601106889917, 0.5342641443616777, '0.00'),
#   Text(-0.27408367205102335, 0.5337397687216375, '0.06'),
#   Text(-0.27510622642380167, 0.5332134321103098, '0.00'),
#   Text(-0.27612777005044004, 0.5326851364614665, '0.06'),
#   Text(-0.27816781005633184, 0.531622675822302, '0.06'),
#   Text(-0.28020376208812425, 0.5305524024181418, '0.06'),
#   Text(-0.28122019576121904, 0.530014340839964, '0.00'),
#   Text(-0.28223559622531996, 0.5294743319778005, '0.06'),
#   Text(-0.28426328260793915, 0.5283884803446787, '0.06'),
#   Text(-0.28628679143695696, 0.5272948634765299, '0.06'),
#   Text(-0.28830609297474247, 0.526193497445226, '0.06'),
#   Text(-0.29032115754549526, 0.5250843984365215, '0.06'),
#   Text(-0.2913270917115608, 0.5245269541547735, '0.00'),
#   Text(-0.2913270917115608, 0.5245269541547735, '0.00'),
#   Text(-0.2913270917115608, 0.5245269541547735, '0.00'),
#   Text(-0.29233195553568164, 0.523967582749815, '0.06'),
#   Text(-0.2943384573944705, 0.5228430667979096, '0.06'),
#   Text(-0.2953400880572079, 0.5222779263824584, '0.00'),
#   Text(-0.2963406336341663, 0.5217108671067728, '0.06'),
#   Text(-0.2983384548306433, 0.5205710003152924, '0.06'),
#   Text(-0.30033189162377766, 0.5194234831750326, '0.06'),
#   Text(-0.30232091471787953, 0.5182683325499876, '0.06'),
#   Text(-0.3043054948821226, 0.5171055654163339, '0.06'),
#   Text(-0.30628560295097457, 0.5159351988621808, '0.06'),
#   Text(-0.30826120982462457, 0.5147572500873191, '0.06'),
#   Text(-0.3102322864694129, 0.5135717364029685, '0.06'),
#   Text(-0.31219880391825544, 0.5123786752315231, '0.06'),
#   Text(-0.3141607332710707, 0.5111780841062957, '0.06'),
#   Text(-0.31611804569520374, 0.5099699806712598, '0.06'),
#   Text(-0.31807071242585133, 0.5087543826807897, '0.06'),
#   Text(-0.3190452946857737, 0.5081437788056327, '0.00'),
#   Text(-0.3200187047664827, 0.5075313079994009, '0.06'),
#   Text(-0.3219619940892626, 0.5063007746014868, '0.06'),
#   Text(-0.3229318661916472, 0.5056827165308104, '0.00'),
#   Text(-0.3239005518354717, 0.5050628005710547, '0.06'),
#   Text(-0.3258343495159264, 0.5038174041014593, '0.06'),
#   Text(-0.32776335871139706, 0.5025646034951368, '0.06'),
#   Text(-0.3296875510730262, 0.5013044171633347, '0.06'),
#   Text(-0.33160689832274454, 0.500036863625842, '0.06'),
#   Text(-0.33352137225368755, 0.49876196151071617, '0.06'),
#   Text(-0.33543094473060875, 0.4974797295540103, '0.06'),
#   Text(-0.3373355876902939, 0.49619018659949726, '0.06'),
#   Text(-0.33828605185121646, 0.4955426794161287, '0.00'),
#   Text(-0.33828605185121646, 0.4955426794161287, '0.00'),
#   Text(-0.3392352731419733, 0.49489335159839304, '0.06'),
#   Text(-0.3401832480751059, 0.49424220553193443, '0.00'),
#   Text(-0.3401832480751059, 0.49424220553193443, '0.00'),
#   Text(-0.34112997316773364, 0.4935892436090775, '0.06'),
#   Text(-0.3430196599229271, 0.4922778817968155, '0.06'),
#   Text(-0.3449043056365814, 0.49095928543347417, '0.06'),
#   Text(-0.3458447294446488, 0.49029728034668685, '0.00'),
#   Text(-0.3467838826118081, 0.4896334738972405, '0.06'),
#   Text(-0.3486583632262088, 0.48830046667233595, '0.06'),
#   Text(-0.3495936837865685, 0.4876312707943746, '0.00'),
#   Text(-0.3505277199322821, 0.4869602833487301, '0.06'),
#   Text(-0.35239192525782775, 0.48561294362185353, '0.06'),
#   Text(-0.3533220875885297, 0.48493659629077623, '0.00'),
#   Text(-0.3533220875885297, 0.48493659629077623, '0.00'),
#   Text(-0.3542509518063504, 0.4842584672923074, '0.06'),
#   Text(-0.3561047722574623, 0.4828968742655733, '0.06'),
#   Text(-0.35795335936728534, 0.48152818455171975, '0.06'),
#   Text(-0.3597966859688506, 0.48015241826510907, '0.06'),
#   Text(-0.3607163681104871, 0.4794618877212031, '0.00'),
#   Text(-0.3616347249724981, 0.47876959562410143, '0.06'),
#   Text(-0.36346744936627445, 0.47737973695075775, '0.06'),
#   Text(-0.36438181016457144, 0.47668217548088593, '0.00'),
#   Text(-0.36438181016457144, 0.47668217548088593, '0.00'),
#   Text(-0.36529483221633086, 0.4759828626705406, '0.06'),
#   Text(-0.36620651216709005, 0.47528180108901175, '0.00'),
#   Text(-0.36711684666731764, 0.4745789933120146, '0.06'),
#   Text(-0.3689334659427796, 0.47316814950654473, '0.06'),
#   Text(-0.3707446633455493, 0.471750351987993, '0.06'),
#   Text(-0.3725504122581403, 0.47032562159241303, '0.06'),
#   Text(-0.37435068614313655, 0.4688939792577453, '0.06'),
#   Text(-0.3752487616793348, 0.4681755726841435, '0.00'),
#   Text(-0.376145458543584, 0.46745544602350814, '0.06'),
#   ...])

# %%
plt.plot(data['PlacedOrNot'],data['Internships'],marker='o')
plt.plot(data['PlacedOrNot'],data['HistoryOfBacklogs'],marker='x')
plt.xlabel('PlacedOrNot')
plt.ylabel('Internships and HistoryOfBacklogs')
# Out:
# Text(0, 0.5, 'Internships and HistoryOfBacklogs')

# %%
plt.plot(data['PlacedOrNot'],data['CGPA'],marker='o')
plt.plot(data['PlacedOrNot'],data['HistoryOfBacklogs'],marker='x')
plt.xlabel('PlacedOrNot')
plt.ylabel('CGPA and HistoryOfBacklogs')
# Out:
# Text(0, 0.5, 'CGPA and HistoryOfBacklogs')

# %%
#Pair Plot
sns.pairplot(data)

# %%
#Heat Map
hm=data.corr()
sns.heatmap(hm)
# Out:
# C:\Users\nagap\AppData\Local\Temp\ipykernel_26952\1719093440.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   hm=data.corr()
# <Axes: >

# %%
#Label Encoding to convert categorical columns to numerical columns
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
data.Gender=le.fit_transform(data.Gender)
data.Gender
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 2961    1
# 2962    1
# 2963    1
# 2964    1
# 2965    1
# Name: Gender, Length: 2966, dtype: int32

# %%
data.Stream=le.fit_transform(data.Stream)
data.Stream
# Out:
# 0       3
# 1       1
# 2       4
# 3       4
# 4       5
#        ..
# 2961    4
# 2962    5
# 2963    4
# 2964    1
# 2965    0
# Name: Stream, Length: 2966, dtype: int32

# %%
#Splitting into dependent and independent variables
x=data.drop(columns=['PlacedOrNot','Hostel'],axis=1)
y=data['PlacedOrNot']

# %%
#Checking Outliers
sns.boxplot(x)
# Out:
# <Axes: >

# %%
#Calculating quartiles for x_independent
quantile = x.quantile(q=[0.25,0.75])
quantile
# Out:
#        Age  Gender  Stream  Internships  CGPA  HistoryOfBacklogs
# 0.25  21.0     1.0     1.0          0.0   6.0                0.0
# 0.75  22.0     1.0     4.0          1.0   8.0                0.0

# %%
#IQR
IQR = quantile.iloc[1] - quantile.iloc[0]
IQR
# Out:
# Age                  1.0
# Gender               0.0
# Stream               3.0
# Internships          1.0
# CGPA                 2.0
# HistoryOfBacklogs    0.0
# dtype: float64

# %%
#calculating upper extreme
upper_extreme = quantile.iloc[1] + (1.5*IQR)
upper_extreme
# Out:
# Age                  23.5
# Gender                1.0
# Stream                8.5
# Internships           2.5
# CGPA                 11.0
# HistoryOfBacklogs     0.0
# dtype: float64

# %%
#calculating lower extreme
lower_extreme = quantile.iloc[0] - (1.5*IQR)
lower_extreme
# Out:
# Age                  19.5
# Gender                1.0
# Stream               -3.5
# Internships          -1.5
# CGPA                  3.0
# HistoryOfBacklogs     0.0
# dtype: float64

# %%
#removing outliers from the extracted numeric columns

removed_outliers = x[(x >=lower_extreme)&(x <=upper_extreme)]
removed_outliers
# Out:
#        Age  Gender  Stream  Internships  CGPA  HistoryOfBacklogs
# 0     22.0     1.0       3          1.0     8                NaN
# 1     21.0     NaN       1          0.0     7                NaN
# 2     22.0     NaN       4          1.0     6                0.0
# 3     21.0     1.0       4          0.0     8                NaN
# 4     22.0     1.0       5          0.0     8                0.0
# ...    ...     ...     ...          ...   ...                ...
# 2961  23.0     1.0       4          0.0     7                0.0
# 2962  23.0     1.0       5          1.0     7                0.0
# 2963  22.0     1.0       4          1.0     7                0.0
# 2964  22.0     1.0       1          1.0     7                0.0
# 2965  23.0     1.0       0          0.0     8                0.0
#
# [2966 rows x 6 columns]

# %%
removed_outliers.to_csv('file1.csv')

# %%
#Finding null values after removing outliers
removed_outliers.isnull().any()
# Out:
# Age                   True
# Gender                True
# Stream               False
# Internships           True
# CGPA                 False
# HistoryOfBacklogs     True
# dtype: bool

# %%
#Replacing null values
removed_outliers['Age'].fillna(removed_outliers['Age'].mean(),inplace=True)
removed_outliers['Gender'].fillna(removed_outliers['Gender'].mean(),inplace=True)
removed_outliers['Internships'].fillna(removed_outliers['Internships'].mean(),inplace=True)
removed_outliers['HistoryOfBacklogs'].fillna(removed_outliers['HistoryOfBacklogs'].mean(),inplace=True)

# %%
#Checking whether null values are removed
removed_outliers.isnull().sum()
# Out:
# Age                  0
# Gender               0
# Stream               0
# Internships          0
# CGPA                 0
# HistoryOfBacklogs    0
# dtype: int64

# %%
removed_outliers
# Out:
#        Age  Gender  Stream  Internships  CGPA  HistoryOfBacklogs
# 0     22.0     1.0       3          1.0     8                0.0
# 1     21.0     1.0       1          0.0     7                0.0
# 2     22.0     1.0       4          1.0     6                0.0
# 3     21.0     1.0       4          0.0     8                0.0
# 4     22.0     1.0       5          0.0     8                0.0
# ...    ...     ...     ...          ...   ...                ...
# 2961  23.0     1.0       4          0.0     7                0.0
# 2962  23.0     1.0       5          1.0     7                0.0
# 2963  22.0     1.0       4          1.0     7                0.0
# 2964  22.0     1.0       1          1.0     7                0.0
# 2965  23.0     1.0       0          0.0     8                0.0
#
# [2966 rows x 6 columns]

# %%
#Removed outliers Boxplot
sns.boxplot(removed_outliers)
# Out:
# <Axes: >

# %% [markdown]
# # Model building

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(removed_outliers,y,test_size = 0.30,random_state = 15)

# %%
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.ensemble import RandomForestClassifier
# from xgboost import XGBClassifier
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.model_selection import RandomizedSearchCV
# from sklearn.metrics import accuracy_score, confusion_matrix
# models = [DecisionTreeClassifier(),RandomForestClassifier(),XGBClassifier(),KNeighborsClassifier()]
# model_name=["Decision Tree","Random Forest","XgBoost","K-Nearest Neighbors"]

# %%
# model_scores=[]
# for model in models:
#     model.fit(x_train, y_train)
#     y_pred = model.predict(x_test) 
#     model_scores.append(accuracy_score(y_test, y_pred))

# %%
# for i in range(len(model_name)):
#     print(model_name[i],str(":"),model_scores[i])

# %%
from xgboost import XGBClassifier
modelxgb=XGBClassifier()

modelxgb.fit(x_train,y_train)

acc_score8 = modelxgb.score(x_test, y_test)
print("model score: %.3f" % acc_score8)

y_pred8=modelxgb.predict(x_test)
# Out:
# model score: 0.884

# %%
from sklearn.ensemble import RandomForestClassifier
modelrf=RandomForestClassifier()

modelrf.fit(x_train,y_train)

acc_scorerf = modelrf.score(x_test, y_test)
print("model score: %.3f" % acc_scorerf)

y_pred4=modelrf.predict(x_test)
# Out:
# model score: 0.890

# %%
# modelxgb.predict([[0.6667,0.0,0.6,0.5,0.75,1.0,0.0]])

new_data = pd.DataFrame({
    'Age': [20],
    'Gender': [1],
    'Stream': [0],
    'Internships': [0],
    'CGPA': [6],
    'HistoryOfBacklogs': [1],
})
predicted_label = modelxgb.predict(new_data)
predicted_label1 = modelrf.predict(new_data)
predicted_label1[0]
# Out:
# 0

# %%
import pickle
pickle.dump(modelxgb,open("model.pkl","wb"))
